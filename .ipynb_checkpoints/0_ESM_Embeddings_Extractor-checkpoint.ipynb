# %%
# !nvidia-smi

# %%
##### install esm
# !pip install fair-esm ### tested on v0.4.0

# %%
### get FASTA files from drive
### MCPAS - origMCPAS_NoMHC
#drive_filepath = '/content/drive/MyDrive/TCR-pMHC-results/mcpas/1_origMCPAS_NoMHC/train_AB/'   #done
#drive_filepath = '/content/drive/MyDrive/TCR-pMHC-results/mcpas/1_origMCPAS_NoMHC/train_B/'    #done

# ### MCPAS - origMCPAS_HMHC
#drive_filepath = '/content/drive/MyDrive/TCR-pMHC-results/mcpas/3_origMCPAS_HMHC/train_AB/'     #done
#drive_filepath = '/content/drive/MyDrive/TCR-pMHC-results/mcpas/3_origMCPAS_HMHC/train_B/'        #don

# ### VDJDB - origVDJDB_NoMHC
#drive_filepath = '/content/drive/MyDrive/TCR-pMHC-results/vdjdb/1_origVDJDB_NoMHC/train_AB/'         #done
# drive_filepath = '/content/drive/MyDrive/TCR-pMHC-results/vdjdb/1_origVDJDB_NoMHC/train_B/'       #done

# ### VDJDB - origVDJDB_HMHC
#drive_filepath = '/content/drive/MyDrive/TCR-pMHC-results/vdjdb/3_origVDJDB_HMHC/train_AB/'  ##done
#drive_filepath = '/content/drive/MyDrive/TCR-pMHC-results/vdjdb/3_origVDJDB_HMHC/train_B/'    ##done

# %%
# drive_filepath = '/content/drive/MyDrive/TCR-pMHC-results/pmtnet_exp/set7/'

# %%
# drive_filepath

# %%
# !cp /content/drive/MyDrive/TCR-pMHC-results/pmtnet_exp/set7/*.fasta '/content'

# %%
#!rm -rf /content/*.csv

# %%
# !mkdir train_cdr3a
# !mkdir train_cdr3b
# !mkdir train_pep

# !mkdir test_cdr3a
# !mkdir test_cdr3b
# !mkdir test_pep

# %%
# !mkdir train_cdr3a
# !mkdir train_cdr3b
# !mkdir train_pep
# !mkdir train_mhc

# !mkdir test_cdr3a
# !mkdir test_cdr3b
# !mkdir test_pep
# !mkdir test_mhc

# %%
# ### TCR-AB

# ## train set

# !python extract.py esm1v_t33_650M_UR90S_1 /content/train_CDR3a.fasta /content/train_cdr3a/ --include mean --truncate

# !python extract.py esm1v_t33_650M_UR90S_1 /content/train_CDR3b.fasta /content/train_cdr3b/ --include mean --truncate

# !python extract.py esm1v_t33_650M_UR90S_1 /content/train_pep.fasta /content/train_pep/ --include mean --truncate

# ##test set


# !python extract.py esm1v_t33_650M_UR90S_1 /content/test_CDR3a.fasta /content/test_cdr3a/ --include mean --truncate

# !python extract.py esm1v_t33_650M_UR90S_1 /content/test_CDR3b.fasta /content/test_cdr3b/ --include mean --truncate

# !python extract.py esm1v_t33_650M_UR90S_1 /content/test_pep.fasta /content/test_pep/ --include mean --truncate

# %%
## TCR - AB-MHC

# ## in case of mhc


# ## train set

# !python extract.py esm1v_t33_650M_UR90S_1 /content/train_CDR3a.fasta /content/train_cdr3a/ --include mean --truncate

# !python extract.py esm1v_t33_650M_UR90S_1 /content/train_CDR3b.fasta /content/train_cdr3b/ --include mean --truncate

# !python extract.py esm1v_t33_650M_UR90S_1 /content/train_pep.fasta /content/train_pep/ --include mean --truncate

# !python extract.py esm1v_t33_650M_UR90S_1 /content/train_mhc.fasta /content/train_mhc/ --include mean --truncate

# ##test set


# !python extract.py esm1v_t33_650M_UR90S_1 /content/test_CDR3a.fasta /content/test_cdr3a/ --include mean --truncate

# !python extract.py esm1v_t33_650M_UR90S_1 /content/test_CDR3b.fasta /content/test_cdr3b/ --include mean --truncate

# !python extract.py esm1v_t33_650M_UR90S_1 /content/test_pep.fasta /content/test_pep/ --include mean --truncate

# !python extract.py esm1v_t33_650M_UR90S_1 /content/test_mhc.fasta /content/test_mhc/ --include mean --truncate

# %%
# !ls -lh

# %%
#### PMTNET

# !python extract.py esm1v_t33_650M_UR90S_1 /content/data_CDR3b.fasta /content/data_cdr3b/ --include mean --truncate

# !python extract.py esm1v_t33_650M_UR90S_1 /content/data_pep.fasta /content/data_pep/ --include mean --truncate

# !python extract.py esm1v_t33_650M_UR90S_1 /content/data_mhc.fasta /content/data_mhc/ --include mean --truncate

# %%
# !zip -qr /content/ESM1v_train_cdr3a.zip /content/train_cdr3a
# !zip -qr /content/ESM1v_train_cdr3b.zip /content/train_cdr3b
# !zip -qr /content/ESM1v_train_pep.zip /content/train_pep



# !zip -qr /content/ESM1v_test_cdr3a.zip /content/test_cdr3a
# !zip -qr /content/ESM1v_test_cdr3b.zip /content/test_cdr3b
# !zip -qr /content/ESM1v_test_pep.zip /content/test_pep

# %%
# # ### in case of AB  MHC


# !zip -qr /content/ESM1v_train_cdr3a.zip /content/train_cdr3a
# !zip -qr /content/ESM1v_train_cdr3b.zip /content/train_cdr3b
# !zip -qr /content/ESM1v_train_pep.zip /content/train_pep
# !zip -qr /content/ESM1v_train_mhc.zip /content/train_mhc


# !zip -qr /content/ESM1v_test_cdr3a.zip /content/test_cdr3a
# !zip -qr /content/ESM1v_test_cdr3b.zip /content/test_cdr3b
# !zip -qr /content/ESM1v_test_pep.zip /content/test_pep
# !zip -qr /content/ESM1v_test_mhc.zip /content/test_mhc

# %%
#### pmtnet

# !zip -qr /content/ESM1v_pmtnet_cdr3b.zip /content/data_cdr3b
# !zip -qr /content/ESM1v_pmtnet_pep.zip   /content/data_pep
# !zip -qr /content/ESM1v_pmtnet_mhc.zip  /content/data_mhc

# %%
# !ls -lh
