# %%
##check GPU
# !nvidia-smi

# %%
#####################################################1_origVDJDB_NoMHC/train_AB
# !cp -r /content/drive/MyDrive/TCR-pMHC-results/vdjdb/1_origVDJDB_NoMHC/train_AB/*.csv '/content/'
# !cp -r /content/drive/MyDrive/TCR-pMHC-results/vdjdb/1_origVDJDB_NoMHC/train_AB/*.zip '/content'



#                                                  #########################################################
# # ###################################################3_origVDJDB_HMHC/train_AB
# !cp -r /content/drive/MyDrive/TCR-pMHC-results/vdjdb/3_origVDJDB_HMHC/train_AB/*.csv '/content/'
# !cp -r /content/drive/MyDrive/TCR-pMHC-results/vdjdb/3_origVDJDB_HMHC/train_AB/*.zip '/content'

# %%
#@title PMETNET
###### pmtnet data


# ### set 1
# !cp -r /content/drive/MyDrive/TCR-pMHC-results/pmtnet_exp/set1/*.csv '/content/'
# !cp -r /content/drive/MyDrive/TCR-pMHC-results/pmtnet_exp/set1/*.zip '/content'


# #### set 2
# !cp -r /content/drive/MyDrive/TCR-pMHC-results/pmtnet_exp/set2/*.csv '/content/'
# !cp -r /content/drive/MyDrive/TCR-pMHC-results/pmtnet_exp/set2/*.zip '/content'


# # #### set 3
# !cp -r /content/drive/MyDrive/TCR-pMHC-results/pmtnet_exp/set3/*.csv '/content/'
# !cp -r /content/drive/MyDrive/TCR-pMHC-results/pmtnet_exp/set3/*.zip '/content'


# #### set 4
# !cp -r /content/drive/MyDrive/TCR-pMHC-results/pmtnet_exp/set4/*.csv '/content/'
# !cp -r /content/drive/MyDrive/TCR-pMHC-results/pmtnet_exp/set4/*.zip '/content'



# #### set 5
# !cp -r /content/drive/MyDrive/TCR-pMHC-results/pmtnet_exp/set5/*.csv '/content/'
# !cp -r /content/drive/MyDrive/TCR-pMHC-results/pmtnet_exp/set5/*.zip '/content'


# #### set 6
# !cp -r /content/drive/MyDrive/TCR-pMHC-results/pmtnet_exp/set6/*.csv '/content/'
# !cp -r /content/drive/MyDrive/TCR-pMHC-results/pmtnet_exp/set6/*.zip '/content'



# #### set 7
# !cp -r /content/drive/MyDrive/TCR-pMHC-results/pmtnet_exp/set7/*.csv '/content/'
# !cp -r /content/drive/MyDrive/TCR-pMHC-results/pmtnet_exp/set7/*.zip '/content'



# #### set 8
# !cp -r /content/drive/MyDrive/TCR-pMHC-results/pmtnet_exp/set8/*.csv '/content/'
# !cp -r /content/drive/MyDrive/TCR-pMHC-results/pmtnet_exp/set8/*.zip '/content'



#### end of set 8

# %%
# ########################################################################## AB and A
# #### unzip train
# !unzip -q /content/ESM1v_train_cdr3a.zip -d /content/train_cdr3a
# !unzip -q /content/ESM1v_train_cdr3b.zip -d /content/train_cdr3b
# !unzip -q /content/ESM1v_train_pep.zip   -d /content/train_peptide


# #### unzip test
# !unzip -q /content/ESM1v_test_cdr3a.zip -d /content/test_cdr3a
# !unzip -q /content/ESM1v_test_cdr3b.zip -d /content/test_cdr3b
# !unzip -q /content/ESM1v_test_pep.zip   -d /content/test_peptide



# # ########################################################################## AB and A wMHC
# # #### unzip train
# !unzip -q /content/ESM1v_train_cdr3a.zip -d /content/train_cdr3a
# !unzip -q /content/ESM1v_train_cdr3b.zip -d /content/train_cdr3b
# !unzip -q /content/ESM1v_train_pep.zip   -d /content/train_peptide
# !unzip -q /content/ESM1v_train_mhc.zip   -d /content/train_mhc



# #### unzip test
# !unzip -q /content/ESM1v_test_cdr3a.zip -d /content/test_cdr3a
# !unzip -q /content/ESM1v_test_cdr3b.zip -d /content/test_cdr3b
# !unzip -q /content/ESM1v_test_pep.zip   -d /content/test_peptide
# !unzip -q /content/ESM1v_test_mhc.zip   -d /content/test_mhc

#### pmtnet
# #### unzip train
#!unzip -q /content/ESM1v_train_cdr3a.zip -d /content/train_cdr3a
# !unzip -q /content/ESM1v_train_cdr3b.zip -d /content/train_cdr3b
# !unzip -q /content/ESM1v_train_pep.zip   -d /content/train_peptide
#!unzip -q /content/ESM1v_train_mhc.zip   -d /content/train_mhc

#### unzip test
#!unzip -q /content/ESM1v_test_cdr3a.zip -d /content/test_cdr3a
# !unzip -q /content/ESM1v_pmtnet_cdr3b.zip -d /content/test_cdr3b
# !unzip -q /content/ESM1v_pmtnet_pep.zip   -d /content/test_peptide
#!unzip -q /content/ESM1v_pmtnet_mhc.zip   -d /content/test_mhc

# %%
import sys
import numpy as np
import pandas as pd
import os
from tqdm import tqdm
from natsort import natsorted
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# %matplotlib inline
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Layer,Input, Dense, Dropout, Activation, Concatenate, Flatten, BatchNormalization
from tensorflow.keras.regularizers import l2,l1
from tensorflow.keras.optimizers import SGD,Adam,RMSprop
#from tensorflow.compat.v1 import InteractiveSession
import tensorflow.keras.backend as K
from tensorflow.keras.preprocessing.image import array_to_img, img_to_array, load_img
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint,ReduceLROnPlateau
from tensorflow.keras.models import load_model
import tensorflow.keras.metrics
####import tensorflow_addons as tfa not required
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.utils import to_categorical, plot_model

# %%
# #!pip install tensorflow-addons
# import tensorflow_addons as tfa
tf.random.set_seed(1)

# %%
import sklearn
import os
from natsort import natsorted
from sklearn.metrics import *

# %%
# ### train files
# ################################################################################ AB and A
# path_train_cdr3a = '/content/train_cdr3a/content/train_cdr3a/'
# path_train_cdr3b = '/content/train_cdr3b/content/train_cdr3b/'
# path_train_pepti = '/content/train_peptide/content/train_pep/'

# ### test files
# path_test_cdr3a = '/content/test_cdr3a/content/test_cdr3a/'
# path_test_cdr3b = '/content/test_cdr3b/content/test_cdr3b/'
# path_test_pepti = '/content/test_peptide/content/test_pep/'



# trainmat_cdr3a = os.listdir(path_train_cdr3a) 
# trainmat_cdr3b = os.listdir(path_train_cdr3b) 
# trainmat_pepti = os.listdir(path_train_pepti)


# testmat_cdr3a = os.listdir(path_test_cdr3a) 
# testmat_cdr3b = os.listdir(path_test_cdr3b) 
# testmat_pepti = os.listdir(path_test_pepti)



# # ################################################################################ AB and A wMHC
# path_train_cdr3a = '/content/train_cdr3a/content/train_cdr3a/'
# path_train_cdr3b = '/content/train_cdr3b/content/train_cdr3b/'
# path_train_pepti = '/content/train_peptide/content/train_pep/'
# path_train_mhc = '/content/train_mhc/content/train_mhc/'

# ### test files
# path_test_cdr3a = '/content/test_cdr3a/content/test_cdr3a/'
# path_test_cdr3b = '/content/test_cdr3b/content/test_cdr3b/'
# path_test_pepti = '/content/test_peptide/content/test_pep/'
# path_test_mhc = '/content/test_mhc/content/test_mhc/'



# trainmat_cdr3a = os.listdir(path_train_cdr3a) 
# trainmat_cdr3b = os.listdir(path_train_cdr3b) 
# trainmat_pepti = os.listdir(path_train_pepti)
# trainmat_mhc   = os.listdir(path_train_mhc)


# testmat_cdr3a = os.listdir(path_test_cdr3a) 
# testmat_cdr3b = os.listdir(path_test_cdr3b) 
# testmat_pepti = os.listdir(path_test_pepti)
# testmat_mhc   = os.listdir(path_test_mhc)

# %%
# # ### pmtnet
# # # # ################################################################################# 
# path_train_cdr3b = '/content/train_cdr3b/content/train_cdr3b/'
# path_train_pepti = '/content/train_peptide/content/train_pep/'

# ### test files
# path_test_cdr3b = '/content/test_cdr3b/content/data_cdr3b/'
# path_test_pepti = '/content/test_peptide/content/data_pep/'


# trainmat_cdr3b = os.listdir(path_train_cdr3b) 
# trainmat_pepti = os.listdir(path_train_pepti)

# testmat_cdr3b = os.listdir(path_test_cdr3b) 
# testmat_pepti = os.listdir(path_test_pepti)

# %%
# ###train ################################################ AB A
# ###train
# train_nmat_cdr3a = natsorted(trainmat_cdr3a)
# train_nmat_cdr3b = natsorted(trainmat_cdr3b)
# train_nmat_pepti = natsorted(trainmat_pepti)



# ###test
# test_nmat_cdr3a = natsorted(testmat_cdr3a)
# test_nmat_cdr3b = natsorted(testmat_cdr3b)
# test_nmat_pepti = natsorted(testmat_pepti)


# # ############################################################# AB  MHC
# ###train
# train_nmat_cdr3a = natsorted(trainmat_cdr3a)
# train_nmat_cdr3b = natsorted(trainmat_cdr3b)
# train_nmat_pepti = natsorted(trainmat_pepti)
# train_nmat_mhc   = natsorted(trainmat_mhc)



# ###test
# test_nmat_cdr3a = natsorted(testmat_cdr3a)
# test_nmat_cdr3b = natsorted(testmat_cdr3b)
# test_nmat_pepti = natsorted(testmat_pepti)
# test_nmat_mhc   = natsorted(testmat_mhc)



############################################################# pmtnet
##train
# train_nmat_cdr3a = natsorted(trainmat_cdr3a)
# train_nmat_cdr3b = natsorted(trainmat_cdr3b)
# train_nmat_pepti = natsorted(trainmat_pepti)
# train_nmat_mhc   = natsorted(trainmat_mhc)



###test
# test_nmat_cdr3a = natsorted(testmat_cdr3a)
# test_nmat_cdr3b = natsorted(testmat_cdr3b)
# test_nmat_pepti = natsorted(testmat_pepti)
# test_nmat_mhc   = natsorted(testmat_mhc)

# %%
# print('train', len(train_nmat_cdr3a), len(train_nmat_cdr3b), len(train_nmat_pepti))
# print('test', len(test_nmat_cdr3a), len(test_nmat_cdr3b), len(test_nmat_pepti))


# print('train', len(train_nmat_cdr3a), len(train_nmat_cdr3b), len(train_nmat_pepti), len(train_nmat_mhc))
# print('test', len(test_nmat_cdr3a), len(test_nmat_cdr3b), len(test_nmat_pepti), len(test_nmat_mhc))


# ##pmtnet
# print('train', len(train_nmat_cdr3b), len(train_nmat_pepti))
# print('test',  len(test_nmat_cdr3b), len(test_nmat_pepti))

# %%
import torch

# %%
from tqdm import tqdm

# %%
train_samples = len(train_nmat_pepti)
test_samples  = len(test_nmat_pepti)
print(train_samples, test_samples)

# %%
# train_matmat_cdr3a = np.zeros((train_samples,1280))
# train_matmat_cdr3b = np.zeros((train_samples,1280))
# train_matmat_pepti = np.zeros((train_samples,1280))


# test_matmat_cdr3a = np.zeros((test_samples,1280))
# test_matmat_cdr3b = np.zeros((test_samples,1280))
# test_matmat_pepti = np.zeros((test_samples,1280))

# ### load train samples 

# for i in tqdm(range(train_samples)):

#   train_matmat_cdr3a[i] = torch.load(path_train_cdr3a+train_nmat_cdr3a[i])['mean_representations'][33]

#   train_matmat_cdr3b[i] = torch.load(path_train_cdr3b+train_nmat_cdr3b[i])['mean_representations'][33]

#   train_matmat_pepti[i] = torch.load(path_train_pepti+train_nmat_pepti[i])['mean_representations'][33]


# for j in tqdm(range(test_samples)):

#   test_matmat_cdr3a[j]  = torch.load(path_test_cdr3a+test_nmat_cdr3a[j])['mean_representations'][33]

#   test_matmat_cdr3b[j]  = torch.load(path_test_cdr3b+test_nmat_cdr3b[j])['mean_representations'][33]

#   test_matmat_pepti[j]  = torch.load(path_test_pepti+test_nmat_pepti[j])['mean_representations'][33]

# %%
###pmtnet

train_matmat_cdr3b = np.zeros((train_samples,1280))
train_matmat_pepti = np.zeros((train_samples,1280))

test_matmat_cdr3b = np.zeros((test_samples,1280))
test_matmat_pepti = np.zeros((test_samples,1280))

### load train samples 

for i in tqdm(range(train_samples)):

  train_matmat_cdr3b[i] = torch.load(path_train_cdr3b+train_nmat_cdr3b[i])['mean_representations'][33]

  train_matmat_pepti[i] = torch.load(path_train_pepti+train_nmat_pepti[i])['mean_representations'][33]


for j in tqdm(range(test_samples)):


  test_matmat_cdr3b[j]  = torch.load(path_test_cdr3b+test_nmat_cdr3b[j])['mean_representations'][33]

  test_matmat_pepti[j]  = torch.load(path_test_pepti+test_nmat_pepti[j])['mean_representations'][33]

# %%
import gc
gc.collect()

# %%
# train_matmat_cdr3a = np.zeros((train_samples,1280))
# train_matmat_cdr3b = np.zeros((train_samples,1280))
# train_matmat_pepti = np.zeros((train_samples,1280))
# train_matmat_mhc   = np.zeros((train_samples,1280))


# test_matmat_cdr3a = np.zeros((test_samples,1280))
# test_matmat_cdr3b = np.zeros((test_samples,1280))
# test_matmat_pepti = np.zeros((test_samples,1280))
# test_matmat_mhc   = np.zeros((test_samples,1280))

# ### load train samples 

# for i in tqdm(range(train_samples)):

#   train_matmat_cdr3a[i] = torch.load(path_train_cdr3a+train_nmat_cdr3a[i])['mean_representations'][33]

#   train_matmat_cdr3b[i] = torch.load(path_train_cdr3b+train_nmat_cdr3b[i])['mean_representations'][33]

#   train_matmat_pepti[i] = torch.load(path_train_pepti+train_nmat_pepti[i])['mean_representations'][33]

#   train_matmat_mhc[i]   = torch.load(path_train_mhc+train_nmat_mhc[i])['mean_representations'][33]


# for j in tqdm(range(test_samples)):

#   test_matmat_cdr3a[j]  = torch.load(path_test_cdr3a+test_nmat_cdr3a[j])['mean_representations'][33]

#   test_matmat_cdr3b[j]  = torch.load(path_test_cdr3b+test_nmat_cdr3b[j])['mean_representations'][33]

#   test_matmat_pepti[j]  = torch.load(path_test_pepti+test_nmat_pepti[j])['mean_representations'][33]

#   test_matmat_mhc[j]    = torch.load(path_test_mhc+test_nmat_mhc[j])['mean_representations'][33]

# %%
# # # # # #get Y
# # # ################################################################


# df_train = pd.read_csv('/content/1_origVDJDB_NoMHC_train_AB.csv')
# df_test = pd.read_csv('/content/4_origVDJDB_NoMHC_test_AB.csv')

# df_train = pd.read_csv('/content/1_origVDJDB_HMHC_train_AB.csv')
# df_test = pd.read_csv('/content/4_origVDJDB_HMHC_test_AB.csv')



################
# df_train = pd.read_csv('/content/1_origMCPAS_noMHC_train_AB.csv')
###       pmtnet


df_test  = pd.read_csv('/content/test6190_set1.csv') #set 1

# df_test  = pd.read_csv('/content/test6190_set2.csv') #set 2

# df_test  = pd.read_csv('/content/test6190_set3.csv') #set 3

# df_test  = pd.read_csv('/content/test6190_set4.csv') #set 4

# df_test  = pd.read_csv('/content/test6190_set5.csv') #set 5

# df_test  = pd.read_csv('/content/test6190_set6.csv') #set 6

# df_test  = pd.read_csv('/content/test6190_set7.csv') #set 7

# df_test  = pd.read_csv('/content/test6190_set8.csv') #set 8

# %%
y_train = df_train['sign'].values.reshape(-1,1)
# y_test  = df_test['sign'].values.reshape(-1,1)


#### pmtnet
y_test  = df_test['label'].values.reshape(-1,1)

# %%
# # ### data

# print('Training', train_matmat_cdr3a.shape, train_matmat_cdr3b.shape, train_matmat_pepti.shape, y_train.shape)
# print('Testing ', test_matmat_cdr3a.shape,  test_matmat_cdr3b.shape,  test_matmat_pepti.shape,  y_test.shape)


# print('Training', train_matmat_cdr3a.shape, train_matmat_cdr3b.shape, train_matmat_pepti.shape, train_matmat_mhc.shape, y_train.shape)
# print('Testing ', test_matmat_cdr3a.shape,  test_matmat_cdr3b.shape,  test_matmat_pepti.shape, test_matmat_mhc.shape, y_test.shape)

##pmtnet

print('Training',  train_matmat_cdr3b.shape, train_matmat_pepti.shape, y_train.shape)
print('Testing ', test_matmat_cdr3b.shape,  test_matmat_pepti.shape, y_test.shape)

# %%
### model
def clear_sess():
  try:
    del model 
    del history 
  except:
    pass
  from tensorflow.keras import backend as K
  K.clear_session()
  import gc
  gc.collect()



  return None

def keras_mcc(y_true, y_pred):
    tp = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    tn = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    fp = K.sum(K.round(K.clip((1 - y_true) * y_pred, 0, 1)))
    fn = K.sum(K.round(K.clip(y_true * (1 - y_pred), 0, 1)))

    num = tp * tn - fp * fn
    den = (tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)
    return num / K.sqrt(den + K.epsilon())

# %%
# clear_sess()
# !rm *.hdf5

# %%
# ['abh', 'bh', 'ah', 'ab', 'b', 'a' ]
# [4,3,3,3,2,2]

# %%
# !rm *.hdf5

# %%
# ####model MLP ############################################################## for CDR3A, CDR3B and peptide  AB
# clear_sess()
# #input_1

# acti='swish'

# input_1 = Input(shape = (1280,), name='i_1')
# dense1_1 = Dense(128, activation = acti)(input_1)
# bn1_1 = BatchNormalization()(dense1_1)
# drop_1 = Dropout(0.5)(bn1_1)

# #input_2
# input_2 = Input(shape = (1280,), name='i_2')
# dense2_1 = Dense(128, activation = acti)(input_2)
# bn2_1 = BatchNormalization()(dense2_1)
# drop_2 = Dropout(0.5)(bn2_1)

# #input_3
# input_3 = Input(shape = (1280,), name='i_3')
# dense3_1 = Dense(128, activation = acti)(input_3)
# bn3_1 = BatchNormalization()(dense3_1)
# drop_3 = Dropout(0.5)(bn3_1)

# # concatenate
# ##concat   = Concatenate()([dense1_1, dense2_1])
# ##concat   = Concatenate()([bn1_1, bn2_1])
# concat   = Concatenate()([drop_1,drop_2,drop_3])
# fc_1   = Dense(512, activation = acti)(concat)
# drop_4 = Dropout(0.5)(fc_1)
# fc_2   = Dense(256, activation = acti)(drop_4)
# #classification output- TCR-Peptide Binding yes/no
# output  = Dense(1, activation = 'sigmoid')(fc_2)
 
# # create model with two inputs
# model = Model(inputs=[input_1,input_2, input_3], outputs=output)

# %%
# !rm *.hdf5

# %%
# ###model MLP ############################################################## for CDR3A, peptide and MHC    AH
# # ####model MLP ############################################################## for CDR3B, peptide and MHC    BH
# # !rm *.hdf5
# clear_sess()


# acti  = 'gelu'
# #input_1


# input_1 = Input(shape = (1280,), name='i_1')
# dense1_1 = Dense(128, activation = acti)(input_1)
# bn1_1 = BatchNormalization()(dense1_1)
# drop_1 = Dropout(0.5)(bn1_1)

# #input_2
# input_2 = Input(shape = (1280,), name='i_2')
# dense2_1 = Dense(128, activation = acti)(input_2)
# bn2_1 = BatchNormalization()(dense2_1)
# drop_2 = Dropout(0.5)(bn2_1)

# #input_3
# input_3 = Input(shape = (1280,), name='i_3')
# dense3_1 = Dense(64, activation = acti)(input_3)
# bn3_1 = BatchNormalization()(dense3_1)
# drop_3 = Dropout(0.5)(bn3_1)

# # concatenate
# ##concat   = Concatenate()([dense1_1, dense2_1])
# ##concat   = Concatenate()([bn1_1, bn2_1])
# concat   = Concatenate()([drop_1,drop_2,drop_3])
# fc_1   = Dense(512, activation = acti)(concat)
# drop_4 = Dropout(0.5)(fc_1)
# fc_2   = Dense(256, activation = acti)(drop_4)
# #classification output- TCR-Peptide Binding yes/no
# output  = Dense(1, activation = 'sigmoid')(fc_2)
 
# # create model with two inputs
# model = Model(inputs=[input_1,input_2, input_3], outputs=output)

# %%
# !rm *.hdf5

# %%
###model MLP ############################################################## for CDR3A peptide A 
###model MLP ############################################################## for CDR3B peptide B 
clear_sess()

acti = 'gelu'

#input_1
input_1 = Input(shape = (1280,), name='i_1')
dense1_1 = Dense(512, activation = acti)(input_1)
bn1_1 = BatchNormalization()(dense1_1)
drop_1 = Dropout(0.5)(bn1_1)

#input_2
input_2 = Input(shape = (1280,), name='i_2')
dense2_1 = Dense(512, activation = acti)(input_2)
bn2_1 = BatchNormalization()(dense2_1)
drop_2 = Dropout(0.5)(bn2_1)


# concatenate
##concat   = Concatenate()([dense1_1, dense2_1])
##concat   = Concatenate()([bn1_1, bn2_1])
concat   = Concatenate()([drop_1,drop_2])
fc_1   = Dense(512, activation = acti)(concat)
drop_4 = Dropout(0.5)(fc_1)
fc_2   = Dense(256, activation = acti)(drop_4)
#classification output- TCR-Peptide Binding yes/no
output  = Dense(1, activation = 'sigmoid')(fc_2)
 
# create model with two inputs
model = Model(inputs=[input_1,input_2], outputs=output)

# %%
# !rm *.hdf5

# %%
# # # ####model MLP ################################################################ for CDR3A CDR3B peptide MHC ABH

# clear_sess()

# acti = 'gelu'

# #input_1
# input_1 = Input(shape = (1280,), name='i_1')
# dense1_1 = Dense(128, activation = acti)(input_1)
# bn1_1 = BatchNormalization()(dense1_1)
# drop_1 = Dropout(0.5)(bn1_1)

# #input_2
# input_2 = Input(shape = (1280,), name='i_2')
# dense2_1 = Dense(128, activation = acti)(input_2)
# bn2_1 = BatchNormalization()(dense2_1)
# drop_2 = Dropout(0.5)(bn2_1)


# #input_3
# input_3 = Input(shape = (1280,), name='i_3')
# dense3_1 = Dense(128, activation = acti)(input_3)
# bn3_1 = BatchNormalization()(dense3_1)
# drop_3 = Dropout(0.5)(bn3_1)

# #input_4
# input_4 = Input(shape = (1280,), name='i_4')
# dense4_1 = Dense(64, activation = acti)(input_4) #256 #64
# bn4_1 = BatchNormalization()(dense4_1)
# drop_4 = Dropout(0.5)(bn4_1)


# # concatenate
# ##concat   = Concatenate()([dense1_1, dense2_1])
# ##concat   = Concatenate()([bn1_1, bn2_1])
# concat   = Concatenate()([drop_1,drop_2, drop_3, drop_4])
# fc_1   = Dense(1024, activation = acti)(concat)
# drop_5 = Dropout(0.5)(fc_1)
# fc_2   = Dense(512, activation = acti)(drop_5)
# #classification output- TCR-Peptide Binding yes/no
# output  = Dense(1, activation = 'sigmoid')(fc_2)
 
# # create model with two inputs
# model = Model(inputs=[input_1,input_2, input_3, input_4], outputs=output)

# %%
# model.summary()

# %%
metrics_c = [tensorflow.keras.metrics.AUC(name="auc_roc",curve="ROC"),tensorflow.keras.metrics.AUC(name="auc_pr",curve="PR"),keras_mcc]
model.compile(loss='binary_crossentropy',optimizer=tensorflow.keras.optimizers.Adam(learning_rate=0.009),metrics=metrics_c)
reduce_lr = ReduceLROnPlateau(monitor='val_keras_mcc', factor=0.95,patience=50, min_lr=0.001, verbose=1)

# %%
##early_stop = EarlyStopping(monitor='loss',min_delta=0,patience=10, verbose=0,mode='min',restore_best_weights=True)

# %%
#checkpoint_filepath = 'weights-improvement-{val_auc_roc:.1f}.hdf5'
checkpoint_filepath_1 = 'weights-improvement-val-loss.hdf5'
model_checkpoint_callback_1 = ModelCheckpoint(filepath=checkpoint_filepath_1,save_weights_only=False,monitor='val_loss',mode='min',save_best_only=True)

checkpoint_filepath_2 = 'weights-improvement-val-auc-roc.hdf5'
model_checkpoint_callback_2 = ModelCheckpoint(filepath=checkpoint_filepath_2,save_weights_only=False,monitor='val_auc_roc',mode='max',save_best_only=True)

checkpoint_filepath_3 = 'weights-improvement-val-auc-pr.hdf5'
model_checkpoint_callback_3 = ModelCheckpoint(filepath=checkpoint_filepath_3,save_weights_only=False,monitor='val_auc_pr',mode='max',save_best_only=True)

checkpoint_filepath_4 = 'weights-improvement-val-keras-mcc.hdf5'
model_checkpoint_callback_4 = ModelCheckpoint(filepath=checkpoint_filepath_4,save_weights_only=False,monitor='val_keras_mcc',mode='max',save_best_only=True)

# %%
# ###fit the keras model for TCRB, peptide,  MHC
# history=model.fit([train_matmat_cdr3b, train_matmat_pepti, train_matmat_mhc],y_train,
#                   batch_size=1024, epochs=800,
#                   validation_data=([test_matmat_cdr3b, test_matmat_pepti, test_matmat_mhc],y_test),
#                   callbacks=[reduce_lr, model_checkpoint_callback_1, model_checkpoint_callback_2,  model_checkpoint_callback_3,model_checkpoint_callback_4,
#                              reduce_lr 
                             
#                              ]
#                   )

# # # ###fit the keras model for TCRA, peptide, MHC
# history=model.fit([train_matmat_cdr3a, train_matmat_pepti,train_matmat_mhc],y_train,
#                   batch_size=1024, epochs=800,
#                   validation_data=([test_matmat_cdr3a, test_matmat_pepti, test_matmat_mhc],y_test),
#                   #class_weight={0: 1.0, 1: 10.0},
#                   callbacks=[model_checkpoint_callback_1, model_checkpoint_callback_2,  model_checkpoint_callback_3,model_checkpoint_callback_4,
#                              reduce_lr 
#                              ]
#                   )


# ###fit the keras model for TCRA, TCRB and peptide
# history=model.fit([train_matmat_cdr3a, train_matmat_cdr3b,train_matmat_pepti],y_train,
#                   batch_size=1024, epochs=800,
#                   validation_data=([test_matmat_cdr3a, test_matmat_cdr3b, test_matmat_pepti],y_test),
#                   #class_weight={0: 1.0, 1: 5.0},
#                   callbacks=[model_checkpoint_callback_1, model_checkpoint_callback_2,  model_checkpoint_callback_3,model_checkpoint_callback_4,reduce_lr]
#                   )

# %%
# # ###fit the keras model for TCRB and peptide


# history=model.fit([train_matmat_cdr3b,train_matmat_pepti],y_train,
#                   batch_size=1024, epochs=1000,
#                   validation_data=([test_matmat_cdr3b, test_matmat_pepti],y_test),
#                   callbacks=[#reduce_lr, 
#                              model_checkpoint_callback_1, model_checkpoint_callback_2,  model_checkpoint_callback_3, model_checkpoint_callback_4,
#                              ],
#                   )


# # ###fit the keras model for TCRA and peptide
# history=model.fit([train_matmat_cdr3a, train_matmat_pepti],y_train,
#                   batch_size=1024, epochs=800,
#                   validation_data=([test_matmat_cdr3a, test_matmat_pepti],y_test),
#                   #class_weight={0: 1.0, 1: 5.0},
#                   callbacks=[model_checkpoint_callback_1, model_checkpoint_callback_2,  model_checkpoint_callback_3, model_checkpoint_callback_4, reduce_lr]
#                   )

# %%
# # ###fit the keras model for TCRA, TCRB , PEP, MHC
# history=model.fit([train_matmat_cdr3a, train_matmat_cdr3b,train_matmat_pepti, train_matmat_mhc],y_train,
#                   batch_size=512, epochs=600,
#                   validation_data=([test_matmat_cdr3a, test_matmat_cdr3b, test_matmat_pepti, test_matmat_mhc],y_test),
#                   #class_weight={0: 1.0, 1: 5.0},
#                   verbose=1,
#                   callbacks=[model_checkpoint_callback_1, model_checkpoint_callback_2,  model_checkpoint_callback_3, model_checkpoint_callback_4,
#                              reduce_lr
#                              ]
#                   )

# %%
# #training plots ##Classification
# fig = plt.figure(figsize=(15,5))

# plt.subplot(1,4,1)
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title("Classification Losses")
# plt.ylabel("Classification Losses")
# plt.xlabel("Epoch")
# plt.legend(["Training Classification Loss","Valid Classification Loss"])

# plt.subplot(1,4,2)
# plt.plot(history.history['auc_pr'])
# plt.plot(history.history['val_auc_pr'])
# plt.title("Classification AUC PR")
# plt.ylabel("Classification AUC PR")
# plt.xlabel("Epoch")
# plt.legend(["Training AUC PR","Valid AUC PR"])

# plt.subplot(1,4,3)
# plt.plot(history.history['auc_roc'])
# plt.plot(history.history['val_auc_roc'])
# plt.title("Classification AUC ROC")
# plt.ylabel("Classification AUC ROC")
# plt.xlabel("Epoch")
# plt.legend(["Training AUC ROC","Valid AUC ROC"])

# plt.subplot(1,4,4)
# plt.plot(history.history['keras_mcc'])
# plt.plot(history.history['val_keras_mcc'])
# plt.title("Classification MCC")
# plt.ylabel("Classification MCC")
# plt.xlabel("Epoch")
# plt.legend(["Training MCC","Valid MCC"])

# plt.show()

# %%
# ['abh', 'bh', 'ah', 'ab', 'b', 'a' ]

# %%
def predict_mode(mode, test_matmat_cdr3a, test_matmat_cdr3b, test_matmat_pepti, test_matmat_mhc, model_loaded, model):

  if   mode=='abh':
    y_pred = model.predict([test_matmat_cdr3a, test_matmat_cdr3b, test_matmat_pepti, test_matmat_mhc])
  elif mode=='bh':
    y_pred = model.predict([test_matmat_cdr3b, test_matmat_pepti, test_matmat_mhc])
  elif mode=='ah':
    y_pred = model.predict([test_matmat_cdr3a, test_matmat_pepti, test_matmat_mhc])
  elif mode=='ab':
    y_pred = model.predict([test_matmat_cdr3a, test_matmat_cdr3b, test_matmat_pepti])
  elif mode=='b':
    y_pred = model.predict([test_matmat_cdr3b, test_matmat_pepti])
  elif mode=='a':
    y_pred = model.predict([ test_matmat_cdr3a, test_matmat_pepti])

  return y_pred

# %%
#mode='ah'
# mode='bh'
#mode='a'
mode='b'
#mode='abh'
#mode='ab'

# %%
train_matmat_cdr3a =0
test_matmat_cdr3a =0

train_matmat_mhc =0
test_matmat_mhc =0

# %%
model_loaded = '/content/weights-improvement-val-keras-mcc.hdf5'
model = tensorflow.keras.models.load_model(model_loaded,compile=False, custom_objects={'metrics_c': keras_mcc})

# y_pred = model.predict([test_matmat_cdr3a, test_matmat_cdr3b, test_matmat_pepti, test_matmat_mhc])
# y_pred = model.predict([test_matmat_cdr3b, test_matmat_pepti, test_matmat_mhc])
#y_pred = model.predict([test_matmat_cdr3a, test_matmat_pepti, test_matmat_mhc])
#y_pred = model.predict([test_matmat_cdr3a, test_matmat_cdr3b, test_matmat_pepti])
y_pred = model.predict([test_matmat_cdr3b, test_matmat_pepti])
#y_pred = model.predict([ test_matmat_cdr3a, test_matmat_pepti])

y_act = y_test.flatten()
y_pred= y_pred.flatten()
y_pred_c=np.where(y_pred>0.5,1,0)


print(roc_auc_score(y_act, y_pred),average_precision_score(y_act, y_pred),matthews_corrcoef(y_act,y_pred_c),cohen_kappa_score(y_act,y_pred_c))

# %%
####model load min loss
model_loaded = '/content/weights-improvement-val-loss.hdf5'
model = tensorflow.keras.models.load_model(model_loaded,compile=False)

y_pred = predict_mode(mode, test_matmat_cdr3a, test_matmat_cdr3b, test_matmat_pepti, test_matmat_mhc, model_loaded, model)


y_act = y_test.flatten()
y_pred= y_pred.flatten()
y_pred_c=np.where(y_pred>0.5,1,0)


print(roc_auc_score(y_act, y_pred),average_precision_score(y_act, y_pred),matthews_corrcoef(y_act,y_pred_c),cohen_kappa_score(y_act,y_pred_c))

# %%
####model load max aucroc


model_loaded = '/content/weights-improvement-val-auc-roc.hdf5'
model = tensorflow.keras.models.load_model(model_loaded,compile=False)

y_pred = predict_mode(mode, test_matmat_cdr3a, test_matmat_cdr3b, test_matmat_pepti, test_matmat_mhc, model_loaded, model)

y_act = y_test.flatten()
y_pred= y_pred.flatten()
y_pred_c=np.where(y_pred>0.5,1,0)


print(roc_auc_score(y_act, y_pred),average_precision_score(y_act, y_pred),matthews_corrcoef(y_act,y_pred_c),cohen_kappa_score(y_act,y_pred_c))

# %%
####model load max aucpr


model_loaded = '/content/weights-improvement-val-auc-pr.hdf5'
model = tensorflow.keras.models.load_model(model_loaded,compile=False)

y_pred = predict_mode(mode, test_matmat_cdr3a, test_matmat_cdr3b, test_matmat_pepti, test_matmat_mhc, model_loaded, model)

y_act = y_test.flatten()
y_pred= y_pred.flatten()
y_pred_c=np.where(y_pred>0.5,1,0)


print(roc_auc_score(y_act, y_pred),average_precision_score(y_act, y_pred),matthews_corrcoef(y_act,y_pred_c),cohen_kappa_score(y_act,y_pred_c))

# %%
model_loaded = '/content/weights-improvement-val-keras-mcc.hdf5'
model = tensorflow.keras.models.load_model(model_loaded,compile=False, custom_objects={'metrics_c': keras_mcc})

#y_pred = model.predict([test_matmat_cdr3a, test_matmat_cdr3b, test_matmat_pepti, test_matmat_mhc])
#y_pred = model.predict([test_matmat_cdr3b, test_matmat_pepti, test_matmat_mhc])
#y_pred = model.predict([test_matmat_cdr3a, test_matmat_pepti, test_matmat_mhc])
#y_pred = model.predict([test_matmat_cdr3a, test_matmat_cdr3b, test_matmat_pepti])
y_pred = model.predict([test_matmat_cdr3b, test_matmat_pepti])
# y_pred = model.predict([ test_matmat_cdr3a, test_matmat_pepti])


y_act = y_test.flatten()
y_pred= y_pred.flatten()
y_pred_c=np.where(y_pred>0.5,1,0)


print(roc_auc_score(y_act, y_pred),average_precision_score(y_act, y_pred),matthews_corrcoef(y_act,y_pred_c),cohen_kappa_score(y_act,y_pred_c))

# %%
# !rm *.hdf5

# %%
# !rm -rf ESM1v_pmtnet_*.zip

# %%
#@title CV runs - make data
#### make_model for 5/10 fold CV
def make_data(orig_matmat_cdr3a, orig_matmat_cdr3b, orig_matmat_pepti, orig_y_train, train_ind, test_ind, mode):

  if mode == 'ab':

    ##dataprep

    matmat_cdr3a   = train_matmat_cdr3a[train_ind]
    matmat_cdr3b   = train_matmat_cdr3b[train_ind]
    matmat_pepti   = train_matmat_pepti[train_ind]
    matmat_y_train = y_train[train_ind]

    #### internal eval
    evalmatmat_cdr3a = train_matmat_cdr3a[test_ind]
    evalmatmat_cdr3b = train_matmat_cdr3b[test_ind]
    evalmatmat_pepti = train_matmat_pepti[test_ind]
    evalmatmat_y_eval= y_train[test_ind]

    train_input = [matmat_cdr3a,matmat_cdr3b,matmat_pepti]
    train_output= matmat_y_train
    test_input = [evalmatmat_cdr3a,evalmatmat_cdr3b,evalmatmat_pepti]
    test_output= evalmatmat_y_eval

    #model

    input_1 = Input(shape = (1280,), name='i_1')
    dense1_1 = Dense(128, activation = 'swish')(input_1)
    bn1_1 = BatchNormalization()(dense1_1)
    drop_1 = Dropout(0.5)(bn1_1)

    #input_2
    input_2 = Input(shape = (1280,), name='i_2')
    dense2_1 = Dense(128, activation = 'swish')(input_2)
    bn2_1 = BatchNormalization()(dense2_1)
    drop_2 = Dropout(0.5)(bn2_1)

    #input_3
    input_3 = Input(shape = (1280,), name='i_3')
    dense3_1 = Dense(128, activation = 'swish')(input_3)
    bn3_1 = BatchNormalization()(dense3_1)
    drop_3 = Dropout(0.5)(bn3_1)

    # concatenate
    ##concat   = Concatenate()([dense1_1, dense2_1])
    ##concat   = Concatenate()([bn1_1, bn2_1])
    concat   = Concatenate()([drop_1,drop_2,drop_3])
    fc_1   = Dense(512, activation = 'swish')(concat)
    drop_4 = Dropout(0.5)(fc_1)
    fc_2   = Dense(256, activation = 'swish')(drop_4)
    #classification output- TCR-Peptide Binding yes/no
    output  = Dense(1, activation = 'sigmoid')(fc_2)

    # create model with two inputs
    model = Model(inputs=[input_1,input_2, input_3], outputs=output)


  elif mode =='a':

    ##data prep

    matmat_cdr3a   = train_matmat_cdr3a[train_ind]
    matmat_pepti   = train_matmat_pepti[train_ind]
    matmat_y_train = y_train[train_ind]

    #### internal eval
    evalmatmat_cdr3a = train_matmat_cdr3a[test_ind]
    evalmatmat_pepti = train_matmat_pepti[test_ind]
    evalmatmat_y_eval= y_train[test_ind]



    train_input = [matmat_cdr3a,matmat_pepti]
    train_output= matmat_y_train
    test_input = [evalmatmat_cdr3a,evalmatmat_pepti]
    test_output= evalmatmat_y_eval


    #model
    #input_1


    input_1 = Input(shape = (1280,), name='i_1')
    dense1_1 = Dense(128, activation = 'swish')(input_1)
    bn1_1 = BatchNormalization()(dense1_1)
    drop_1 = Dropout(0.5)(bn1_1)

    #input_2
    input_2 = Input(shape = (1280,), name='i_2')
    dense2_1 = Dense(128, activation = 'swish')(input_2)
    bn2_1 = BatchNormalization()(dense2_1)
    drop_2 = Dropout(0.5)(bn2_1)


    # concatenate
    ##concat   = Concatenate()([dense1_1, dense2_1])
    ##concat   = Concatenate()([bn1_1, bn2_1])
    concat   = Concatenate()([drop_1,drop_2])
    fc_1   = Dense(512, activation = 'swish')(concat)
    drop_4 = Dropout(0.5)(fc_1)
    fc_2   = Dense(256, activation = 'swish')(drop_4)
    #classification output- TCR-Peptide Binding yes/no
    output  = Dense(1, activation = 'sigmoid')(fc_2)

    # create model with two inputs
    model = Model(inputs=[input_1,input_2], outputs=output)


  elif mode == 'b':

    #model

    matmat_cdr3b   = train_matmat_cdr3b[train_ind]
    matmat_pepti   = train_matmat_pepti[train_ind]
    matmat_y_train = y_train[train_ind]

    #### internal eval
    evalmatmat_cdr3b = train_matmat_cdr3b[test_ind]
    evalmatmat_pepti = train_matmat_pepti[test_ind]
    evalmatmat_y_eval= y_train[test_ind]



    train_input = [matmat_cdr3b,matmat_pepti]
    train_output= matmat_y_train
    test_input = [evalmatmat_cdr3b,evalmatmat_pepti]
    test_output= evalmatmat_y_eval


    #input_1


    input_1 = Input(shape = (1280,), name='i_1')
    dense1_1 = Dense(128, activation = 'swish')(input_1)
    bn1_1 = BatchNormalization()(dense1_1)
    drop_1 = Dropout(0.5)(bn1_1)

    #input_2
    input_2 = Input(shape = (1280,), name='i_2')
    dense2_1 = Dense(128, activation = 'swish')(input_2)
    bn2_1 = BatchNormalization()(dense2_1)
    drop_2 = Dropout(0.5)(bn2_1)


    # concatenate
    ##concat   = Concatenate()([dense1_1, dense2_1])
    ##concat   = Concatenate()([bn1_1, bn2_1])
    concat   = Concatenate()([drop_1,drop_2])
    fc_1   = Dense(512, activation = 'swish')(concat)
    drop_4 = Dropout(0.5)(fc_1)
    fc_2   = Dense(256, activation = 'swish')(drop_4)
    #classification output- TCR-Peptide Binding yes/no
    output  = Dense(1, activation = 'sigmoid')(fc_2)

    # create model with two inputs
    model = Model(inputs=[input_1,input_2], outputs=output)

  elif mode == 'abh':

    ##dataprep

    matmat_cdr3a   = train_matmat_cdr3a[train_ind]
    matmat_cdr3b   = train_matmat_cdr3b[train_ind]
    matmat_pepti   = train_matmat_pepti[train_ind]
    matmat_mhc     = train_matmat_mhc[train_ind]
    matmat_y_train = y_train[train_ind]

    #### internal eval
    evalmatmat_cdr3a = train_matmat_cdr3a[test_ind]
    evalmatmat_cdr3b = train_matmat_cdr3b[test_ind]
    evalmatmat_pepti = train_matmat_pepti[test_ind]
    evalmatmat_mhc   = train_matmat_mhc[test_ind]
    evalmatmat_y_eval= y_train[test_ind]

    train_input = [matmat_cdr3a,matmat_cdr3b,matmat_pepti, matmat_mhc]
    train_output= matmat_y_train
    test_input = [evalmatmat_cdr3a,evalmatmat_cdr3b,evalmatmat_pepti, evalmatmat_mhc]
    test_output= evalmatmat_y_eval

    #input_1
    input_1 = Input(shape = (1280,), name='i_1')
    dense1_1 = Dense(128, activation = 'swish')(input_1)
    bn1_1 = BatchNormalization()(dense1_1)
    drop_1 = Dropout(0.5)(bn1_1)

    #input_2
    input_2 = Input(shape = (1280,), name='i_2')
    dense2_1 = Dense(128, activation = 'swish')(input_2)
    bn2_1 = BatchNormalization()(dense2_1)
    drop_2 = Dropout(0.5)(bn2_1)


    #input_3
    input_3 = Input(shape = (1280,), name='i_3')
    dense3_1 = Dense(128, activation = 'swish')(input_3)
    bn3_1 = BatchNormalization()(dense3_1)
    drop_3 = Dropout(0.5)(bn3_1)

    #input_4
    input_4 = Input(shape = (1280,), name='i_4')
    dense4_1 = Dense(16, activation = 'swish')(input_4)
    bn4_1 = BatchNormalization()(dense4_1)
    drop_4 = Dropout(0.5)(bn4_1)


    # concatenate
    ##concat   = Concatenate()([dense1_1, dense2_1])
    ##concat   = Concatenate()([bn1_1, bn2_1])
    concat   = Concatenate()([drop_1,drop_2, drop_3, drop_4])
    fc_1   = Dense(256, activation = 'swish')(concat)
    drop_5 = Dropout(0.5)(fc_1)
    fc_2   = Dense(256, activation = 'swish')(drop_5)
    #classification output- TCR-Peptide Binding yes/no
    output  = Dense(1, activation = 'sigmoid')(fc_2)
    
    # create model with two inputs
    model = Model(inputs=[input_1,input_2, input_3, input_4], outputs=output)


  elif mode == 'bh':

    ##dataprep

    matmat_cdr3b   = train_matmat_cdr3b[train_ind]
    matmat_pepti   = train_matmat_pepti[train_ind]
    matmat_mhc     = train_matmat_mhc[train_ind]
    matmat_y_train = y_train[train_ind]

    #### internal eval
    evalmatmat_cdr3b = train_matmat_cdr3b[test_ind]
    evalmatmat_pepti = train_matmat_pepti[test_ind]
    evalmatmat_mhc   = train_matmat_mhc[test_ind]
    evalmatmat_y_eval= y_train[test_ind]

    train_input = [matmat_cdr3b,matmat_pepti, matmat_mhc]
    train_output= matmat_y_train
    test_input = [evalmatmat_cdr3b,evalmatmat_pepti, evalmatmat_mhc]
    test_output= evalmatmat_y_eval


    #input_2
    input_2 = Input(shape = (1280,), name='i_2')
    dense2_1 = Dense(128, activation = 'swish')(input_2)
    bn2_1 = BatchNormalization()(dense2_1)
    drop_2 = Dropout(0.5)(bn2_1)


    #input_3
    input_3 = Input(shape = (1280,), name='i_3')
    dense3_1 = Dense(128, activation = 'swish')(input_3)
    bn3_1 = BatchNormalization()(dense3_1)
    drop_3 = Dropout(0.5)(bn3_1)

    #input_4
    input_4 = Input(shape = (1280,), name='i_4')
    dense4_1 = Dense(128, activation = 'swish')(input_4)
    bn4_1 = BatchNormalization()(dense4_1)
    drop_4 = Dropout(0.5)(bn4_1)


    # concatenate
    ##concat   = Concatenate()([dense1_1, dense2_1])
    ##concat   = Concatenate()([bn1_1, bn2_1])
    concat   = Concatenate()([drop_2, drop_3, drop_4])
    fc_1   = Dense(512, activation = 'swish')(concat)
    drop_5 = Dropout(0.5)(fc_1)
    fc_2   = Dense(256, activation = 'swish')(drop_5)
    #classification output- TCR-Peptide Binding yes/no
    output  = Dense(1, activation = 'sigmoid')(fc_2)
    
    # create model with two inputs
    model = Model(inputs=[input_2, input_3, input_4], outputs=output)

  elif mode == 'ah':

    ##dataprep

    matmat_cdr3a   = train_matmat_cdr3a[train_ind]
    matmat_pepti   = train_matmat_pepti[train_ind]
    matmat_mhc     = train_matmat_mhc[train_ind]
    matmat_y_train = y_train[train_ind]

    #### internal eval
    evalmatmat_cdr3a = train_matmat_cdr3a[test_ind]
    evalmatmat_pepti = train_matmat_pepti[test_ind]
    evalmatmat_mhc   = train_matmat_mhc[test_ind]
    evalmatmat_y_eval= y_train[test_ind]

    train_input = [matmat_cdr3a,matmat_pepti, matmat_mhc]
    train_output= matmat_y_train
    test_input = [evalmatmat_cdr3a,evalmatmat_pepti, evalmatmat_mhc]
    test_output= evalmatmat_y_eval

    #input_1
    input_1 = Input(shape = (1280,), name='i_1')
    dense1_1 = Dense(128, activation = 'swish')(input_1)
    bn1_1 = BatchNormalization()(dense1_1)
    drop_1 = Dropout(0.5)(bn1_1)

    #input_3
    input_3 = Input(shape = (1280,), name='i_3')
    dense3_1 = Dense(128, activation = 'swish')(input_3)
    bn3_1 = BatchNormalization()(dense3_1)
    drop_3 = Dropout(0.5)(bn3_1)

    #input_4
    input_4 = Input(shape = (1280,), name='i_4')
    dense4_1 = Dense(128, activation = 'swish')(input_4)
    bn4_1 = BatchNormalization()(dense4_1)
    drop_4 = Dropout(0.5)(bn4_1)


    # concatenate
    ##concat   = Concatenate()([dense1_1, dense2_1])
    ##concat   = Concatenate()([bn1_1, bn2_1])
    concat   = Concatenate()([drop_1, drop_3, drop_4])
    fc_1   = Dense(512, activation = 'swish')(concat)
    drop_5 = Dropout(0.5)(fc_1)
    fc_2   = Dense(256, activation = 'swish')(drop_5)
    #classification output- TCR-Peptide Binding yes/no
    output  = Dense(1, activation = 'sigmoid')(fc_2)
    
    # create model with two inputs
    model = Model(inputs=[input_1, input_3, input_4], outputs=output)

  return model, train_input, test_input, train_output, test_output

# %%
#### make_model for 5/10 fold CV

def make_data(orig_matmat_cdr3a, orig_matmat_cdr3b, orig_matmat_pepti, orig_matmat_mhc, orig_y_train, train_ind, test_ind, mode):

  acti = 'gelu'

  if mode == 'ab':

    ##dataprep

    matmat_cdr3a   = train_matmat_cdr3a[train_ind]
    matmat_cdr3b   = train_matmat_cdr3b[train_ind]
    matmat_pepti   = train_matmat_pepti[train_ind]
    matmat_y_train = y_train[train_ind]

    #### internal eval
    evalmatmat_cdr3a = train_matmat_cdr3a[test_ind]
    evalmatmat_cdr3b = train_matmat_cdr3b[test_ind]
    evalmatmat_pepti = train_matmat_pepti[test_ind]
    evalmatmat_y_eval= y_train[test_ind]

    train_input = [matmat_cdr3a,matmat_cdr3b,matmat_pepti]
    train_output= matmat_y_train
    test_input = [evalmatmat_cdr3a,evalmatmat_cdr3b,evalmatmat_pepti]
    test_output= evalmatmat_y_eval

    #model

    input_1 = Input(shape = (1280,), name='i_1')
    dense1_1 = Dense(128, activation = acti)(input_1)
    bn1_1 = BatchNormalization()(dense1_1)
    drop_1 = Dropout(0.5)(bn1_1)

    #input_2
    input_2 = Input(shape = (1280,), name='i_2')
    dense2_1 = Dense(128, activation = acti)(input_2)
    bn2_1 = BatchNormalization()(dense2_1)
    drop_2 = Dropout(0.5)(bn2_1)

    #input_3
    input_3 = Input(shape = (1280,), name='i_3')
    dense3_1 = Dense(128, activation = acti)(input_3)
    bn3_1 = BatchNormalization()(dense3_1)
    drop_3 = Dropout(0.5)(bn3_1)

    # concatenate
    ##concat   = Concatenate()([dense1_1, dense2_1])
    ##concat   = Concatenate()([bn1_1, bn2_1])
    concat   = Concatenate()([drop_1,drop_2,drop_3])
    fc_1   = Dense(512, activation = acti)(concat)
    drop_4 = Dropout(0.5)(fc_1)
    fc_2   = Dense(256, activation = acti)(drop_4)
    #classification output- TCR-Peptide Binding yes/no
    output  = Dense(1, activation = 'sigmoid')(fc_2)

    # create model with two inputs
    model = Model(inputs=[input_1,input_2, input_3], outputs=output)


  elif mode =='a':

    ##data prep

    matmat_cdr3a   = train_matmat_cdr3a[train_ind]
    matmat_pepti   = train_matmat_pepti[train_ind]
    matmat_y_train = y_train[train_ind]

    #### internal eval
    evalmatmat_cdr3a = train_matmat_cdr3a[test_ind]
    evalmatmat_pepti = train_matmat_pepti[test_ind]
    evalmatmat_y_eval= y_train[test_ind]



    train_input = [matmat_cdr3a,matmat_pepti]
    train_output= matmat_y_train
    test_input = [evalmatmat_cdr3a,evalmatmat_pepti]
    test_output= evalmatmat_y_eval


    #model
    #input_1


    input_1 = Input(shape = (1280,), name='i_1')
    dense1_1 = Dense(128, activation = acti)(input_1)
    bn1_1 = BatchNormalization()(dense1_1)
    drop_1 = Dropout(0.5)(bn1_1)

    #input_2
    input_2 = Input(shape = (1280,), name='i_2')
    dense2_1 = Dense(128, activation = acti)(input_2)
    bn2_1 = BatchNormalization()(dense2_1)
    drop_2 = Dropout(0.5)(bn2_1)


    # concatenate
    ##concat   = Concatenate()([dense1_1, dense2_1])
    ##concat   = Concatenate()([bn1_1, bn2_1])
    concat   = Concatenate()([drop_1,drop_2])
    fc_1   = Dense(512, activation = acti)(concat)
    drop_4 = Dropout(0.5)(fc_1)
    fc_2   = Dense(256, activation = acti)(drop_4)
    #classification output- TCR-Peptide Binding yes/no
    output  = Dense(1, activation = 'sigmoid')(fc_2)

    # create model with two inputs
    model = Model(inputs=[input_1,input_2], outputs=output)


  elif mode == 'b':

    #model

    matmat_cdr3b   = train_matmat_cdr3b[train_ind]
    matmat_pepti   = train_matmat_pepti[train_ind]
    matmat_y_train = y_train[train_ind]

    #### internal eval
    evalmatmat_cdr3b = train_matmat_cdr3b[test_ind]
    evalmatmat_pepti = train_matmat_pepti[test_ind]
    evalmatmat_y_eval= y_train[test_ind]



    train_input = [matmat_cdr3b,matmat_pepti]
    train_output= matmat_y_train
    test_input = [evalmatmat_cdr3b,evalmatmat_pepti]
    test_output= evalmatmat_y_eval


    #input_1


    input_1 = Input(shape = (1280,), name='i_1')
    dense1_1 = Dense(128, activation = acti)(input_1)
    bn1_1 = BatchNormalization()(dense1_1)
    drop_1 = Dropout(0.5)(bn1_1)

    #input_2
    input_2 = Input(shape = (1280,), name='i_2')
    dense2_1 = Dense(128, activation = acti)(input_2)
    bn2_1 = BatchNormalization()(dense2_1)
    drop_2 = Dropout(0.5)(bn2_1)


    # concatenate
    ##concat   = Concatenate()([dense1_1, dense2_1])
    ##concat   = Concatenate()([bn1_1, bn2_1])
    concat   = Concatenate()([drop_1,drop_2])
    fc_1   = Dense(512, activation = acti)(concat)
    drop_4 = Dropout(0.5)(fc_1)
    fc_2   = Dense(256, activation = acti)(drop_4)
    #classification output- TCR-Peptide Binding yes/no
    output  = Dense(1, activation = 'sigmoid')(fc_2)

    # create model with two inputs
    model = Model(inputs=[input_1,input_2], outputs=output)

  elif mode == 'abh':

    ##dataprep

    matmat_cdr3a   = train_matmat_cdr3a[train_ind]
    matmat_cdr3b   = train_matmat_cdr3b[train_ind]
    matmat_pepti   = train_matmat_pepti[train_ind]
    matmat_mhc     = train_matmat_mhc[train_ind]
    matmat_y_train = y_train[train_ind]

    #### internal eval
    evalmatmat_cdr3a = train_matmat_cdr3a[test_ind]
    evalmatmat_cdr3b = train_matmat_cdr3b[test_ind]
    evalmatmat_pepti = train_matmat_pepti[test_ind]
    evalmatmat_mhc   = train_matmat_mhc[test_ind]
    evalmatmat_y_eval= y_train[test_ind]

    train_input = [matmat_cdr3a,matmat_cdr3b,matmat_pepti, matmat_mhc]
    train_output= matmat_y_train
    test_input = [evalmatmat_cdr3a,evalmatmat_cdr3b,evalmatmat_pepti, evalmatmat_mhc]
    test_output= evalmatmat_y_eval

    #input_1
    input_1 = Input(shape = (1280,), name='i_1')
    dense1_1 = Dense(128, activation = acti)(input_1)
    bn1_1 = BatchNormalization()(dense1_1)
    drop_1 = Dropout(0.5)(bn1_1)

    #input_2
    input_2 = Input(shape = (1280,), name='i_2')
    dense2_1 = Dense(128, activation = acti)(input_2)
    bn2_1 = BatchNormalization()(dense2_1)
    drop_2 = Dropout(0.5)(bn2_1)


    #input_3
    input_3 = Input(shape = (1280,), name='i_3')
    dense3_1 = Dense(128, activation = acti)(input_3)
    bn3_1 = BatchNormalization()(dense3_1)
    drop_3 = Dropout(0.5)(bn3_1)

    #input_4
    input_4 = Input(shape = (4,), name='i_4')
    dense4_1 = Dense(4, activation = acti)(input_4)
    bn4_1 = BatchNormalization()(dense4_1)
    drop_4 = Dropout(0.5)(bn4_1)


    # concatenate
    ##concat   = Concatenate()([dense1_1, dense2_1])
    ##concat   = Concatenate()([bn1_1, bn2_1])
    concat   = Concatenate()([drop_1,drop_2, drop_3, drop_4])
    fc_1   = Dense(512, activation = acti)(concat)
    drop_5 = Dropout(0.5)(fc_1)
    fc_2   = Dense(256, activation = acti)(drop_5)
    #classification output- TCR-Peptide Binding yes/no
    output  = Dense(1, activation = 'sigmoid')(fc_2)
    
    # create model with two inputs
    model = Model(inputs=[input_1,input_2, input_3, input_4], outputs=output)


  elif mode == 'bh':

    ##dataprep

    matmat_cdr3b   = train_matmat_cdr3b[train_ind]
    matmat_pepti   = train_matmat_pepti[train_ind]
    matmat_mhc     = train_matmat_mhc[train_ind]
    matmat_y_train = y_train[train_ind]

    #### internal eval
    evalmatmat_cdr3b = train_matmat_cdr3b[test_ind]
    evalmatmat_pepti = train_matmat_pepti[test_ind]
    evalmatmat_mhc   = train_matmat_mhc[test_ind]
    evalmatmat_y_eval= y_train[test_ind]

    train_input = [matmat_cdr3b,matmat_pepti, matmat_mhc]
    train_output= matmat_y_train
    test_input = [evalmatmat_cdr3b,evalmatmat_pepti, evalmatmat_mhc]
    test_output= evalmatmat_y_eval


    #input_2
    input_2 = Input(shape = (1280,), name='i_2')
    dense2_1 = Dense(128, activation = acti)(input_2)
    bn2_1 = BatchNormalization()(dense2_1)
    drop_2 = Dropout(0.5)(bn2_1)


    #input_3
    input_3 = Input(shape = (1280,), name='i_3')
    dense3_1 = Dense(128, activation = acti)(input_3)
    bn3_1 = BatchNormalization()(dense3_1)
    drop_3 = Dropout(0.5)(bn3_1)

    #input_4
    input_4 = Input(shape = (1280,), name='i_4')
    dense4_1 = Dense(64, activation = acti)(input_4)
    bn4_1 = BatchNormalization()(dense4_1)
    drop_4 = Dropout(0.5)(bn4_1)


    # concatenate
    ##concat   = Concatenate()([dense1_1, dense2_1])
    ##concat   = Concatenate()([bn1_1, bn2_1])
    concat   = Concatenate()([drop_2, drop_3, drop_4])
    fc_1   = Dense(512, activation = acti)(concat)
    drop_5 = Dropout(0.5)(fc_1)
    fc_2   = Dense(256, activation = acti)(drop_5)
    #classification output- TCR-Peptide Binding yes/no
    output  = Dense(1, activation = 'sigmoid')(fc_2)
    
    # create model with two inputs
    model = Model(inputs=[input_2, input_3, input_4], outputs=output)

  elif mode == 'ah':

    ##dataprep

    matmat_cdr3a   = train_matmat_cdr3a[train_ind]
    matmat_pepti   = train_matmat_pepti[train_ind]
    matmat_mhc     = train_matmat_mhc[train_ind]
    matmat_y_train = y_train[train_ind]

    #### internal eval
    evalmatmat_cdr3a = train_matmat_cdr3a[test_ind]
    evalmatmat_pepti = train_matmat_pepti[test_ind]
    evalmatmat_mhc   = train_matmat_mhc[test_ind]
    evalmatmat_y_eval= y_train[test_ind]

    train_input = [matmat_cdr3a,matmat_pepti, matmat_mhc]
    train_output= matmat_y_train
    test_input = [evalmatmat_cdr3a,evalmatmat_pepti, evalmatmat_mhc]
    test_output= evalmatmat_y_eval

    #input_1
    input_1 = Input(shape = (1280,), name='i_1')
    dense1_1 = Dense(128, activation = acti)(input_1)
    bn1_1 = BatchNormalization()(dense1_1)
    drop_1 = Dropout(0.5)(bn1_1)

    #input_3
    input_3 = Input(shape = (1280,), name='i_3')
    dense3_1 = Dense(128, activation = acti)(input_3)
    bn3_1 = BatchNormalization()(dense3_1)
    drop_3 = Dropout(0.5)(bn3_1)

    #input_4
    input_4 = Input(shape = (1280,), name='i_4')
    dense4_1 = Dense(1, activation = acti)(input_4)
    bn4_1 = BatchNormalization()(dense4_1)
    drop_4 = Dropout(0.5)(bn4_1)


    # concatenate
    ##concat   = Concatenate()([dense1_1, dense2_1])
    ##concat   = Concatenate()([bn1_1, bn2_1])
    concat   = Concatenate()([drop_1, drop_3, drop_4])
    fc_1   = Dense(512, activation = acti)(concat)
    drop_5 = Dropout(0.5)(fc_1)
    fc_2   = Dense(256, activation = acti)(drop_5)
    #classification output- TCR-Peptide Binding yes/no
    output  = Dense(1, activation = 'sigmoid')(fc_2)
    
    # create model with two inputs
    model = Model(inputs=[input_1, input_3, input_4], outputs=output)

  return model, train_input, test_input, train_output, test_output

# %%
# ['abh', 'bh', 'ah', 'ab', 'b', 'a' ]
from tqdm.notebook import tqdm

# %%
#### 10 Fold CV

###set mode
mode='abh'


from sklearn.model_selection import KFold
# Define the K-fold Cross Validator
kfold = KFold(n_splits=10, shuffle=True)

# K-fold Cross Validation model evaluation
fold_no = 1

for train_ind, test_ind in tqdm(kfold.split(train_matmat_pepti)):
  clear_sess()
  #print('------------------------------------------------------------------------')
  #print(f'Training for fold {fold_no} ...')
  #print('Train shape',train_ind.shape, 'Test shape',test_ind.shape)

  #model, train_input, test_input, train_output, test_output = make_data(train_matmat_cdr3a, train_matmat_cdr3b, train_matmat_pepti, y_train, train_ind, test_ind, mode)
  model, train_input, test_input, train_output, test_output = make_data(train_matmat_cdr3a, train_matmat_cdr3b, train_matmat_pepti, train_mhc_encoded, y_train, train_ind, test_ind, mode)

  #print('Training', train_input[0].shape, train_input[1].shape, train_input[2].shape, train_output.shape)
  #print('Evaluation', test_input[0].shape, test_input[1].shape, test_input[2].shape, test_output.shape)

  #print(len(train_input),len(test_input))
  #metrics_c = [tensorflow.keras.metrics.AUC(name="auc_pr",curve="PR"),tensorflow.keras.metrics.AUC(name="auc_roc",curve="ROC")]
  metrics_c = [tensorflow.keras.metrics.AUC(name="auc_roc",curve="ROC"),tensorflow.keras.metrics.AUC(name="auc_pr",curve="PR"),keras_mcc]
  model.compile(loss="binary_crossentropy", optimizer=Adam(learning_rate=0.009), metrics=metrics_c )
  #early_stop = EarlyStopping(monitor='loss',min_delta=0,patience=10, verbose=0,mode='min',restore_best_weights=True)
  #reduce_lr = ReduceLROnPlateau(monitor='val_keras_mcc', factor=0.,patience=20, min_lr=0.0000001, verbose=0)
  reduce_lr = ReduceLROnPlateau(monitor='val_keras_mcc', factor=0.9,patience=50, min_lr=0.001, verbose=0)
  checkpoint_filepath = f'weights-improvement-{fold_no}.hdf5'
  model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath,save_weights_only=False,monitor='val_keras_mcc',mode='max',save_best_only=True)


  history = model.fit(train_input, train_output,epochs=800,batch_size=1024, verbose=0, validation_data=(test_input,test_output),
                  callbacks=[model_checkpoint_callback, reduce_lr])

  model_loaded = f'weights-improvement-{fold_no}.hdf5'
  model = tensorflow.keras.models.load_model(model_loaded,compile=False)

  y_pred = model.predict(test_input, verbose=0)
  y_act = test_output.flatten()
  y_pred= y_pred.flatten()
  y_pred_c=np.where(y_pred>0.5,1,0)
  print(#roc_auc_score(y_act, y_pred),average_precision_score(y_act, y_pred),
        matthews_corrcoef(y_act,y_pred_c)#,cohen_kappa_score(y_act,y_pred_c)
        )
  fold_no = fold_no + 1

# %%
# !rm *.hdf5

# %%
#### 10 Fold CV

###set mode
mode='bh'


from sklearn.model_selection import KFold
# Define the K-fold Cross Validator
kfold = KFold(n_splits=10, shuffle=True)

# K-fold Cross Validation model evaluation
fold_no = 1

for train_ind, test_ind in tqdm(kfold.split(train_matmat_pepti)):
  clear_sess()
  #print('------------------------------------------------------------------------')
  #print(f'Training for fold {fold_no} ...')
  #print('Train shape',train_ind.shape, 'Test shape',test_ind.shape)

  #model, train_input, test_input, train_output, test_output = make_data(train_matmat_cdr3a, train_matmat_cdr3b, train_matmat_pepti, y_train, train_ind, test_ind, mode)
  model, train_input, test_input, train_output, test_output = make_data(train_matmat_cdr3a, train_matmat_cdr3b, train_matmat_pepti, train_matmat_mhc, y_train, train_ind, test_ind, mode)

  #print('Training', train_input[0].shape, train_input[1].shape, train_input[2].shape, train_output.shape)
  #print('Evaluation', test_input[0].shape, test_input[1].shape, test_input[2].shape, test_output.shape)

  #print(len(train_input),len(test_input))
  #metrics_c = [tensorflow.keras.metrics.AUC(name="auc_pr",curve="PR"),tensorflow.keras.metrics.AUC(name="auc_roc",curve="ROC")]
  metrics_c = [tensorflow.keras.metrics.AUC(name="auc_roc",curve="ROC"),tensorflow.keras.metrics.AUC(name="auc_pr",curve="PR"),keras_mcc]
  model.compile(loss="binary_crossentropy", optimizer=Adam(learning_rate=0.008), metrics=metrics_c )
  #early_stop = EarlyStopping(monitor='loss',min_delta=0,patience=10, verbose=0,mode='min',restore_best_weights=True)
  #reduce_lr = ReduceLROnPlateau(monitor='val_keras_mcc', factor=0.,patience=20, min_lr=0.0000001, verbose=0)
  reduce_lr = ReduceLROnPlateau(monitor='val_keras_mcc', factor=0.95,patience=50, min_lr=0.004, verbose=0)
  checkpoint_filepath = f'weights-improvement-{fold_no}.hdf5'
  model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath,save_weights_only=False,monitor='val_keras_mcc',mode='max',save_best_only=True)


  history = model.fit(train_input, train_output,epochs=800,batch_size=1024, verbose=0, validation_data=(test_input,test_output),
                  callbacks=[model_checkpoint_callback, reduce_lr])

  model_loaded = f'weights-improvement-{fold_no}.hdf5'
  model = tensorflow.keras.models.load_model(model_loaded,compile=False)

  y_pred = model.predict(test_input, verbose=0)
  y_act = test_output.flatten()
  y_pred= y_pred.flatten()
  y_pred_c=np.where(y_pred>0.5,1,0)
  print(#roc_auc_score(y_act, y_pred),average_precision_score(y_act, y_pred),
        matthews_corrcoef(y_act,y_pred_c)#,cohen_kappa_score(y_act,y_pred_c)
        )
  fold_no = fold_no + 1

# %%
# !rm *.hdf5

# %%
#### 10 Fold CV

###set mode
mode='ah'


from sklearn.model_selection import KFold
# Define the K-fold Cross Validator
kfold = KFold(n_splits=10, shuffle=True)

# K-fold Cross Validation model evaluation
fold_no = 1

for train_ind, test_ind in tqdm(kfold.split(train_matmat_pepti)):
  clear_sess()
  #print('------------------------------------------------------------------------')
  #print(f'Training for fold {fold_no} ...')
  #print('Train shape',train_ind.shape, 'Test shape',test_ind.shape)

  #model, train_input, test_input, train_output, test_output = make_data(train_matmat_cdr3a, train_matmat_cdr3b, train_matmat_pepti, y_train, train_ind, test_ind, mode)
  model, train_input, test_input, train_output, test_output = make_data(train_matmat_cdr3a, train_matmat_cdr3b, train_matmat_pepti, train_matmat_mhc, y_train, train_ind, test_ind, mode)

  #print('Training', train_input[0].shape, train_input[1].shape, train_input[2].shape, train_output.shape)
  #print('Evaluation', test_input[0].shape, test_input[1].shape, test_input[2].shape, test_output.shape)

  #print(len(train_input),len(test_input))
  #metrics_c = [tensorflow.keras.metrics.AUC(name="auc_pr",curve="PR"),tensorflow.keras.metrics.AUC(name="auc_roc",curve="ROC")]
  metrics_c = [tensorflow.keras.metrics.AUC(name="auc_roc",curve="ROC"),tensorflow.keras.metrics.AUC(name="auc_pr",curve="PR"),keras_mcc]
  model.compile(loss="binary_crossentropy", optimizer=Adam(learning_rate=0.008), metrics=metrics_c )
  #early_stop = EarlyStopping(monitor='loss',min_delta=0,patience=10, verbose=0,mode='min',restore_best_weights=True)
  #reduce_lr = ReduceLROnPlateau(monitor='val_keras_mcc', factor=0.,patience=20, min_lr=0.0000001, verbose=0)
  reduce_lr = ReduceLROnPlateau(monitor='val_keras_mcc', factor=0.95,patience=50, min_lr=0.005, verbose=0)
  checkpoint_filepath = f'weights-improvement-{fold_no}.hdf5'
  model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath,save_weights_only=False,monitor='val_keras_mcc',mode='max',save_best_only=True)


  history = model.fit(train_input, train_output,epochs=800,batch_size=1024, verbose=0, validation_data=(test_input,test_output),
                  callbacks=[model_checkpoint_callback, reduce_lr])

  model_loaded = f'weights-improvement-{fold_no}.hdf5'
  model = tensorflow.keras.models.load_model(model_loaded,compile=False)

  y_pred = model.predict(test_input, verbose=0)
  y_act = test_output.flatten()
  y_pred= y_pred.flatten()
  y_pred_c=np.where(y_pred>0.5,1,0)
  print(#roc_auc_score(y_act, y_pred),average_precision_score(y_act, y_pred),
        matthews_corrcoef(y_act,y_pred_c)#,cohen_kappa_score(y_act,y_pred_c)
        )
  fold_no = fold_no + 1

# %%
# !rm *.hdf5

# %%
#### 10 Fold CV

###set mode
mode='ab'


from sklearn.model_selection import KFold
# Define the K-fold Cross Validator
kfold = KFold(n_splits=10, shuffle=True)

# K-fold Cross Validation model evaluation
fold_no = 1

for train_ind, test_ind in tqdm(kfold.split(train_matmat_pepti)):
  clear_sess()
  #print('------------------------------------------------------------------------')
  #print(f'Training for fold {fold_no} ...')
  #print('Train shape',train_ind.shape, 'Test shape',test_ind.shape)

  #model, train_input, test_input, train_output, test_output = make_data(train_matmat_cdr3a, train_matmat_cdr3b, train_matmat_pepti, y_train, train_ind, test_ind, mode)
  model, train_input, test_input, train_output, test_output = make_data(train_matmat_cdr3a, train_matmat_cdr3b, train_matmat_pepti, train_matmat_mhc, y_train, train_ind, test_ind, mode)

  #print('Training', train_input[0].shape, train_input[1].shape, train_input[2].shape, train_output.shape)
  #print('Evaluation', test_input[0].shape, test_input[1].shape, test_input[2].shape, test_output.shape)

  #print(len(train_input),len(test_input))
  #metrics_c = [tensorflow.keras.metrics.AUC(name="auc_pr",curve="PR"),tensorflow.keras.metrics.AUC(name="auc_roc",curve="ROC")]
  metrics_c = [tensorflow.keras.metrics.AUC(name="auc_roc",curve="ROC"),tensorflow.keras.metrics.AUC(name="auc_pr",curve="PR"),keras_mcc]
  model.compile(loss="binary_crossentropy", optimizer=Adam(learning_rate=0.008), metrics=metrics_c )
  #early_stop = EarlyStopping(monitor='loss',min_delta=0,patience=10, verbose=0,mode='min',restore_best_weights=True)
  #reduce_lr = ReduceLROnPlateau(monitor='val_keras_mcc', factor=0.,patience=20, min_lr=0.0000001, verbose=0)
  reduce_lr = ReduceLROnPlateau(monitor='val_keras_mcc', factor=0.95,patience=50, min_lr=0.004, verbose=0)
  checkpoint_filepath = f'weights-improvement-{fold_no}.hdf5'
  model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath,save_weights_only=False,monitor='val_keras_mcc',mode='max',save_best_only=True)


  history = model.fit(train_input, train_output,epochs=800,batch_size=1024, verbose=0, validation_data=(test_input,test_output),
                  callbacks=[model_checkpoint_callback, reduce_lr])

  model_loaded = f'weights-improvement-{fold_no}.hdf5'
  model = tensorflow.keras.models.load_model(model_loaded,compile=False)

  y_pred = model.predict(test_input, verbose=0)
  y_act = test_output.flatten()
  y_pred= y_pred.flatten()
  y_pred_c=np.where(y_pred>0.5,1,0)
  print(#roc_auc_score(y_act, y_pred),average_precision_score(y_act, y_pred),
        matthews_corrcoef(y_act,y_pred_c)#,cohen_kappa_score(y_act,y_pred_c)
        )
  fold_no = fold_no + 1

# %%
# !rm *.hdf5

# %%
#### 10 Fold CV

###set mode
#mode='a'
mode='b'



from sklearn.model_selection import KFold
# Define the K-fold Cross Validator
kfold = KFold(n_splits=10, shuffle=True)

# K-fold Cross Validation model evaluation
fold_no = 1

for train_ind, test_ind in kfold.split(train_matmat_pepti):
  clear_sess()
  #print('------------------------------------------------------------------------')
  #print(f'Training for fold {fold_no} ...')
  #print('Train shape',train_ind.shape, 'Test shape',test_ind.shape)

  model, train_input, test_input, train_output, test_output = make_data(train_matmat_cdr3a, train_matmat_cdr3b, train_matmat_pepti, train_matmat_mhc, y_train, train_ind, test_ind, mode)

  #print('Training', train_input[0].shape, train_input[1].shape, train_input[2].shape, train_output.shape)
  #print('Evaluation', test_input[0].shape, test_input[1].shape, test_input[2].shape, test_output.shape)

  metrics_c = [tensorflow.keras.metrics.AUC(name="auc_roc",curve="ROC"),tensorflow.keras.metrics.AUC(name="auc_pr",curve="PR"),keras_mcc]
  #metrics_c = [keras_mcc]
  model.compile(loss="binary_crossentropy", optimizer=Adam(learning_rate=0.008), metrics=metrics_c )
  #early_stop = EarlyStopping(monitor='loss',min_delta=0,patience=10, verbose=0,mode='min',restore_best_weights=True)
  reduce_lr = ReduceLROnPlateau(monitor='val_keras_mcc', factor=0.95,patience=20, min_lr=0.005, verbose=0)
  checkpoint_filepath = f'weights-improvement-{fold_no}.hdf5'
  #model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath,save_weights_only=False,monitor='val_auc_pr',mode='max',save_best_only=True)
  model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath,save_weights_only=False,monitor='val_keras_mcc',mode='max',save_best_only=True)


  history = model.fit(train_input, train_output,epochs=600,batch_size=1024, verbose=0, validation_data=(test_input,test_output),
                      
                  callbacks=[model_checkpoint_callback,reduce_lr])

  model_loaded = f'weights-improvement-{fold_no}.hdf5'
  model = tensorflow.keras.models.load_model(model_loaded,compile=False)

  y_pred = model.predict(test_input, verbose=0)
  y_act = test_output.flatten()
  y_pred= y_pred.flatten()
  y_pred_c=np.where(y_pred>0.5,1,0)
  print(#roc_auc_score(y_act, y_pred),average_precision_score(y_act, y_pred),
        matthews_corrcoef(y_act,y_pred_c),#cohen_kappa_score(y_act,y_pred_c)
        )
  fold_no = fold_no + 1

# %%
from sklearn.model_selection import StratifiedKFold

# %%
#### 10 Fold CV

###set mode
mode='abh'



# from sklearn.model_selection import KFold
# # Define the K-fold Cross Validator
# kfold = KFold(n_splits=10, shuffle=True)

stkfold = StratifiedKFold(n_splits=10)

# K-fold Cross Validation model evaluation
fold_no = 1

for train_ind, test_ind in stkfold.split(train_matmat_pepti,y_train):
  clear_sess()
  #print('------------------------------------------------------------------------')
  #print(f'Training for fold {fold_no} ...')
  #print('Train shape',train_ind.shape, 'Test shape',test_ind.shape)

  #model, train_input, test_input, train_output, test_output = make_data(train_matmat_cdr3a, train_matmat_cdr3b, train_matmat_pepti, train_matmat_mhc, y_train, train_ind, test_ind, mode)

  model, train_input, test_input, train_output, test_output = make_data(train_matmat_cdr3a, train_matmat_cdr3b, train_matmat_pepti, train_mhc_encoded, y_train, train_ind, test_ind, mode)

  #print('Training', train_input[0].shape, train_input[1].shape, train_input[2].shape, train_output.shape)
  #print('Evaluation', test_input[0].shape, test_input[1].shape, test_input[2].shape, test_output.shape)

  metrics_c = [tensorflow.keras.metrics.AUC(name="auc_roc",curve="ROC"),tensorflow.keras.metrics.AUC(name="auc_pr",curve="PR"),keras_mcc]
  #metrics_c = [keras_mcc]
  model.compile(loss="binary_crossentropy", optimizer=Adam(learning_rate=0.009), metrics=metrics_c )
  #early_stop = EarlyStopping(monitor='loss',min_delta=0,patience=10, verbose=0,mode='min',restore_best_weights=True)
  reduce_lr = ReduceLROnPlateau(monitor='val_keras_mcc', factor=0.95,patience=20, min_lr=0.001, verbose=0)
  checkpoint_filepath = f'weights-improvement-{fold_no}.hdf5'
  #model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath,save_weights_only=False,monitor='val_auc_pr',mode='max',save_best_only=True)
  model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath,save_weights_only=False,monitor='val_keras_mcc',mode='max',save_best_only=True)


  history = model.fit(train_input, train_output,epochs=800,batch_size=1024, verbose=0, validation_data=(test_input,test_output),
                  class_weight={0: 1.0, 1: 5.0},
                  callbacks=[model_checkpoint_callback,reduce_lr])

  model_loaded = f'weights-improvement-{fold_no}.hdf5'
  model = tensorflow.keras.models.load_model(model_loaded,compile=False)

  y_pred = model.predict(test_input, verbose=0)
  y_act = test_output.flatten()
  y_pred= y_pred.flatten()
  y_pred_c=np.where(y_pred>0.5,1,0)
  print(#roc_auc_score(y_act, y_pred),average_precision_score(y_act, y_pred),
        matthews_corrcoef(y_act,y_pred_c),#cohen_kappa_score(y_act,y_pred_c)
        )
  fold_no = fold_no + 1

# %%
# !rm *.hdf5

# %%
train_matmat_cdr3a =0
test_matmat_cdr3a =0

# %%
#### 10 Fold CV

###set mode
mode='b'



from sklearn.model_selection import KFold
# Define the K-fold Cross Validator
kfold = KFold(n_splits=10, shuffle=True, random_state=0)

# K-fold Cross Validation model evaluation
fold_no = 1

for train_ind, test_ind in kfold.split(train_matmat_pepti):
  clear_sess()
  #print('------------------------------------------------------------------------')
  #print(f'Training for fold {fold_no} ...')
  #print('Train shape',train_ind.shape, 'Test shape',test_ind.shape)

  model, train_input, test_input, train_output, test_output = make_data(train_matmat_cdr3a, train_matmat_cdr3b, train_matmat_pepti, train_matmat_mhc, y_train, train_ind, test_ind, mode)

  #print('Training', train_input[0].shape, train_input[1].shape, train_input[2].shape, train_output.shape)
  #print('Evaluation', test_input[0].shape, test_input[1].shape, test_input[2].shape, test_output.shape)

  metrics_c = [tensorflow.keras.metrics.AUC(name="auc_roc",curve="ROC"),tensorflow.keras.metrics.AUC(name="auc_pr",curve="PR"),keras_mcc]
  #metrics_c = [keras_mcc]
  model.compile(loss="binary_crossentropy", optimizer=Adam(learning_rate=0.008), metrics=metrics_c)
  #early_stop = EarlyStopping(monitor='loss',min_delta=0,patience=10, verbose=0,mode='min',restore_best_weights=True)
  reduce_lr = ReduceLROnPlateau(monitor='val_auc_roc', factor=0.95,patience=50, min_lr=0.004, verbose=0)
  checkpoint_filepath = f'weights-improvement-{fold_no}.hdf5'
  #model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath,save_weights_only=False,monitor='val_auc_pr',mode='max',save_best_only=True)
  model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath,save_weights_only=False,monitor='val_keras_mcc',mode='max',save_best_only=True)


  history = model.fit(train_input, train_output,epochs=800,batch_size=1024, verbose=0, validation_data=(test_input,test_output),
                  callbacks=[model_checkpoint_callback, reduce_lr])

  model_loaded = f'weights-improvement-{fold_no}.hdf5'
  model = tensorflow.keras.models.load_model(model_loaded,compile=False)

  y_pred = model.predict(test_input, verbose=0)
  y_act = test_output.flatten()
  y_pred= y_pred.flatten()
  y_pred_c=np.where(y_pred>0.5,1,0)
  print(#roc_auc_score(y_act, y_pred),average_precision_score(y_act, y_pred),
        matthews_corrcoef(y_act,y_pred_c),#cohen_kappa_score(y_act,y_pred_c)
        )
  fold_no = fold_no + 1

# %%
######## PMTNET OOD

# %%
# c_tcrb = 'CASSVPGAGEETQY'

# intermediate_output_fil_2 =  intermediate_output_fil[df_test_pepfil['CDR3']==c_tcrb]
# df_test_pepfil_2 = df_test_pepfil[df_test_pepfil['CDR3']==c_tcrb]

# %%
# intermediate_output_fil_2.shape, df_test_pepfil_2.shape

# %%
# c_tcrb = 'CASSRTGSTYEQYF'

# intermediate_output_fil =  intermediate_output_1[df_test['CDR3']==c_tcrb]
# df_test_pepfil = df_test[df_test['CDR3']==c_tcrb]

# %%
intermediate_output_fil.shape, df_test_pepfil.shape

# %%
from collections import Counter

# %%
Counter(df_test_pepfil['label'].values)

# %%
# reducer = TSNE(n_components=2, verbose=0, perplexity=10, n_iter=1000, metric='euclidean')
# results_tsne = reducer.fit_transform(intermediate_output_fil)

# reducer = TSNE(n_components=2, verbose=0, perplexity=2, n_iter=1000, metric='euclidean')
# results_tsne = reducer.fit_transform(intermediate_output_fil_2)

# %%
# %matplotlib inline
import seaborn as sns

# %%
reducer = TSNE(n_components=2, verbose=0, perplexity=10, n_iter=5000, metric='euclidean')
results_tsne = reducer.fit_transform(intermediate_output_fil)

# %%
plt.rcParams.update(plt.rcParamsDefault)
sns.set(font_scale=0.5)
sns.set_style('ticks')
df_subset = pd.DataFrame()

df_subset['tsne-1'] = results_tsne[:,0]
df_subset['tsne-2'] = results_tsne[:,1]
# df_subset['Binding']           = df_test_pepfil_2['label'].values.flatten()
df_subset['Binding']           = df_test_pepfil['label'].values.flatten()

rep_dict = {0:'Negative', 1:'Positive'}
df_subset.replace({"Binding": rep_dict },inplace=True)

plt.figure(figsize=(8,8))
ax = sns.scatterplot(
    x="tsne-1", y="tsne-2",
    hue="Binding",
    palette=sns.color_palette("tab10", 2)[::-1],
    # palette=sns.color_palette("tab10", 2),
    data = df_subset,
    legend="full",
    alpha=0.9,
    s=50
)

# handles_ax, labels_ax = ax.get_legend_handles_labels()
# plt.legend(reversed(handles_ax), reversed(labels_ax), title='TCR Binding', loc='lower right',)
plt.legend(title='TCR Binding')
# plt.xlim(-500,500)
# plt.ylim(-500,500)
plt.title(c_pep)

for r in range(df_subset.shape[0]):
  plt.text(x=df_subset['tsne-1'].values.tolist()[r], y=df_subset['tsne-2'].values.tolist()[r], s=df_test_pepfil['CDR3'].values.tolist()[r])
# plt.title('CASPGLAGEYEQYF')
sns.despine(offset=5, trim=True)
plt.grid()
# plt.show()
plt.savefig('TCRESM_VDJDB_'+c_pep, bbox_inches='tight', dpi=600)
