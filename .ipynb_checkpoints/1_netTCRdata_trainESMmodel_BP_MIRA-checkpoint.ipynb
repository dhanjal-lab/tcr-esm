# %%
# !nvidia-smi

# %%
###!cp -r '/content/drive/MyDrive/TCR-pMHC-results/ESM1v_cdr3a.zip' '/content'


####################################################################################################### TCR_beta_90
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_90/ESM1v_cdr3b.zip' '/content'
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_90/ESM1v_peptide.zip' '/content'
# eval
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_90/ESM1v_mira_cdr3b.zip' '/content'
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_90/ESM1v_mira_peptide.zip' '/content'
## actual csv
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_90/train_beta_90.csv' '/content'
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_90/mira_eval_threshold90.csv' '/content'
############################################################################################################################################

# # # ########################################################################################################  TCR_beta_92
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_92/ESM1v_cdr3b.zip' '/content'
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_92/ESM1v_peptide.zip' '/content'
# # eval
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_92/ESM1v_mira_cdr3b.zip' '/content'
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_92/ESM1v_mira_peptide.zip' '/content'
# ## actual csv
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_92/train_beta_92.csv' '/content'
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_92/mira_eval_threshold92.csv' '/content'




# # # ########################################################################################################  TCR_beta_94
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_94/ESM1v_cdr3b.zip' '/content'
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_94/ESM1v_peptide.zip' '/content'
# # eval
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_94/ESM1v_mira_cdr3b.zip' '/content'
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_94/ESM1v_mira_peptide.zip' '/content'
# ## actual csv
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_94/train_beta_94.csv' '/content'
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_94/mira_eval_threshold94.csv' '/content'


# # # ########################################################################################################  TCR_beta_99
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_99/ESM1v_cdr3b.zip' '/content'
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_99/ESM1v_peptide.zip' '/content'
# # eval
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_99/ESM1v_mira_cdr3b.zip' '/content'
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_99/ESM1v_mira_peptide.zip' '/content'
# ## actual csv
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_99/train_beta_99.csv' '/content'
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_99/mira_eval_threshold99.csv' '/content'

# # ## with mira 100

# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_99/ESM1v_mira100_cdr3b.zip' '/content'
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_99/ESM1v_mira100_peptide.zip' '/content'
# ## actual csv
# !cp -r '/content/drive/MyDrive/TCR-pMHC-results/netTCR/TCR_beta_99/mira_eval_threshold100.csv' '/content'

# %%
#### unzip train
# !unzip -q /content/ESM1v_cdr3b.zip -d /content/train_cdr3b
# !unzip -q /content/ESM1v_peptide.zip -d /content/train_peptide



### unzip eval
# !unzip -q /content/ESM1v_mira_cdr3b.zip -d /content/mira_cdr3b
# !unzip -q /content/ESM1v_mira_peptide.zip -d /content/mira_peptide


# ######################################################################### mira 99 mira 100
# #### unzip train
# !unzip -q /content/ESM1v_cdr3b.zip -d /content/train_cdr3b
# !unzip -q /content/ESM1v_peptide.zip -d /content/train_peptide



# ### unzip eval
# !unzip -q /content/ESM1v_mira_cdr3b.zip -d /content/mira_cdr3b
# !unzip -q /content/ESM1v_mira_peptide.zip -d /content/mira_peptide

# ### unzip eval
# !unzip -q /content/ESM1v_mira100_cdr3b.zip -d /content/mira100_cdr3b
# !unzip -q /content/ESM1v_mira100_peptide.zip -d /content/mira100_peptide

# %%
import sys
import numpy as np
import pandas as pd
import os
from tqdm import tqdm
from natsort import natsorted
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# %matplotlib inline
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Layer,Input, Dense, Dropout, Activation, Concatenate, Flatten, BatchNormalization
from tensorflow.keras.regularizers import l2,l1
from tensorflow.keras.optimizers import SGD,Adam,RMSprop
#from tensorflow.compat.v1 import InteractiveSession
import tensorflow.keras.backend as K
from tensorflow.keras.preprocessing.image import array_to_img, img_to_array, load_img
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint,ReduceLROnPlateau
from tensorflow.keras.models import load_model
import tensorflow.keras.metrics
####import tensorflow_addons as tfa not required
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.utils import to_categorical, plot_model

# %%
# #!pip install tensorflow-addons
# import tensorflow_addons as tfa
tf.random.set_seed(1)

# %%
import sklearn
import os
from natsort import natsorted
from sklearn.metrics import *

# %%
### train files


path_train_cdr3b = '/content/train_cdr3b/content/cdr3b/'
path_train_pepti = '/content/train_peptide/content/peptide/'

mat_cdr3b = os.listdir(path_train_cdr3b) 
mat_pepti = os.listdir(path_train_pepti)



# ### eval other than mira 100


path_eval_cdr3b = '/content/mira_cdr3b/content/mira_cdr3b/'
path_eval_pepti = '/content/mira_peptide/content/mira_peptide/'



evalmat_cdr3b = os.listdir(path_eval_cdr3b) 
evalmat_pepti = os.listdir(path_eval_pepti)


# #### eval mira 100 
# path_eval_cdr3b = '/content/mira100_cdr3b/content/mira100_cdr3b/'
# path_eval_pepti = '/content/mira100_peptide/content/mira100_peptide/'



# evalmat_cdr3b = os.listdir(path_eval_cdr3b) 
# evalmat_pepti = os.listdir(path_eval_pepti)

# %%
###train
mat_cdr3b = natsorted(mat_cdr3b)
mat_pepti = natsorted(mat_pepti)


###eval
evalmat_cdr3b = natsorted(evalmat_cdr3b)
evalmat_pepti = natsorted(evalmat_pepti)

# %%
len(mat_cdr3b), len(evalmat_pepti) ### TCR_beta_90 53952 total samples; 636 in mira dataset

# %%
import torch

# %%
from tqdm import tqdm

# %%
orig_matmat_cdr3b = np.zeros((len(mat_cdr3b),1280))
orig_matmat_pepti = np.zeros((len(mat_cdr3b),1280))
orig_evalmatmat_cdr3b = np.zeros((len(evalmat_pepti) ,1280))
orig_evalmatmat_pepti = np.zeros((len(evalmat_pepti) ,1280))

### load train samples 

for i in tqdm(range(len(mat_cdr3b))):

  x = torch.load(path_train_cdr3b+mat_cdr3b[i])['mean_representations'][33]
  orig_matmat_cdr3b[i] = x

  y = torch.load(path_train_pepti+mat_pepti[i])['mean_representations'][33]
  orig_matmat_pepti[i] = y


### load eval samples

for j in tqdm(range(len(evalmat_pepti))):

  z = torch.load(path_eval_cdr3b+evalmat_cdr3b[j])['mean_representations'][33]
  orig_evalmatmat_cdr3b[j] = z

  t = torch.load(path_eval_pepti+evalmat_pepti[j])['mean_representations'][33]
  orig_evalmatmat_pepti[j] = t

# %%
##get Y
################################################################ TCR_beta_90
df_train = pd.read_csv('/content/train_beta_90.csv')
df_eval = pd.read_csv('/content/mira_eval_threshold90.csv')

# # ################################################################## TCR_beta_92
# df_train = pd.read_csv('/content/train_beta_92.csv')
# df_eval = pd.read_csv('/content/mira_eval_threshold92.csv')



# # ################################################################## TCR_beta_94
# df_train = pd.read_csv('/content/train_beta_94.csv')
# df_eval = pd.read_csv('/content/mira_eval_threshold94.csv')


# ################################################################## TCR_beta_99
# df_train = pd.read_csv('/content/train_beta_99.csv')
# df_eval = pd.read_csv('/content/mira_eval_threshold99.csv')

##mira100
# df_eval = pd.read_csv('/content/mira_eval_threshold100.csv')

# %%
y_train = df_train['binder'].values
y_eval  = df_eval['binder'].values

# %%
orig_y_train = y_train.reshape(-1,1)
orig_y_eval = y_eval.reshape(-1,1)

# %%
#mode = 'cv'
mode = 'eval'


######## get CV splits from original data

if mode=='cv':
  train_list = [3,4,1,2]
  test_list  = [5]


  matmat_cdr3b = orig_matmat_cdr3b[df_train['partition'].isin(train_list)]
  matmat_pepti = orig_matmat_pepti[df_train['partition'].isin(train_list)]
  y_train      = orig_y_train[df_train['partition'].isin(train_list)]

  #### internal eval
  evalmatmat_cdr3b = orig_matmat_cdr3b[df_train['partition'].isin(test_list)]
  evalmatmat_pepti = orig_matmat_pepti[df_train['partition'].isin(test_list)]
  y_eval           = orig_y_train[df_train['partition'].isin(test_list)]

elif mode=='eval':
  matmat_cdr3b = orig_matmat_cdr3b
  matmat_pepti = orig_matmat_pepti
  y_train      = orig_y_train

  #### on test
  evalmatmat_cdr3b = orig_evalmatmat_cdr3b
  evalmatmat_pepti = orig_evalmatmat_pepti
  y_eval           = orig_y_eval

# %%
### data

print('Training', matmat_cdr3b.shape, matmat_pepti.shape, y_train.shape)
print('Evaluation', evalmatmat_cdr3b.shape, evalmatmat_pepti.shape, y_eval.shape)

# %%
## class weights


from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight(class_weight = "balanced",
                                        classes = np.unique(orig_y_train.squeeze()),
                                        y = orig_y_train.squeeze())
#class_weights = dict(zip(np.unique(train_classes), class_weights)),
class_weights

# %%
# print(train_cdr3b.shape, test_cdr3b.shape, train_pep.shape, test_pep.shape, train_Y.shape, test_Y.shape)

# %%
# print(train_cdr3a.shape, test_cdr3a.shape, train_cdr3b.shape, test_cdr3b.shape, train_pep.shape, test_pep.shape, train_Y.shape, test_Y.shape)

# %%
### model
def clear_sess():
  try:
    del model 
    del history 
  except:
    pass
  from tensorflow.keras import backend as K
  K.clear_session()
  import gc
  gc.collect()



  return None

# %%
clear_sess()
# !rm *.hdf5

# %%
# # ####model MLP ## for CDR3a with CDR3b and peptide
# clear_sess()
# #input_1

# input_1 = Input(shape = (1280,), name='i_1')
# dense1_1 = Dense(128, activation = 'relu')(input_1)
# bn1_1 = BatchNormalization()(dense1_1)

# #input_2
# input_2 = Input(shape = (1280,), name='i_2')
# dense2_1 = Dense(128, activation = 'relu')(input_2)
# bn2_1 = BatchNormalization()(dense2_1)

# #input_3
# input_3 = Input(shape = (1280,), name='i_3')
# dense3_1 = Dense(128, activation = 'relu')(input_3)
# bn3_1 = BatchNormalization()(dense3_1)
 
# # concatenate
# ##concat   = Concatenate()([dense1_1, dense2_1])
# concat   = Concatenate()([bn1_1, bn2_1, bn3_1])
# fc_1   = Dense(512, activation = 'relu')(concat)
# #drop_1 = Dropout(0.5)(fc_1)
# fc_2   = Dense(256, activation = 'relu')(fc_1)
# #classification output
# output  = Dense(1, activation = 'sigmoid')(fc_2)
 
# # create model with two inputs
# model = Model(inputs=[input_1,input_2, input_3], outputs=output)


# # ####model MLP ## for  CDR3b-peptide and CDR3a-peptide
# clear_sess()
# #input_1

# input_1 = Input(shape = (1280,), name='i_1')
# dense1_1 = Dense(128, activation = 'relu')(input_1)
# bn1_1 = BatchNormalization()(dense1_1)

# #input_2
# input_2 = Input(shape = (1280,), name='i_2')
# dense2_1 = Dense(128, activation = 'relu')(input_2)
# bn2_1 = BatchNormalization()(dense2_1)


# # concatenate
# ##concat   = Concatenate()([dense1_1, dense2_1])
# concat   = Concatenate()([bn1_1, bn2_1])
# fc_1   = Dense(512, activation = 'relu')(concat)
# #drop_1 = Dropout(0.5)(fc_1)
# fc_2   = Dense(256, activation = 'relu')(fc_1)
# #classification output
# output  = Dense(1, activation = 'sigmoid')(fc_2)
 
# # create model with two inputs
# model = Model(inputs=[input_1,input_2], outputs=output)

# %%
model.summary()

# %%
def keras_mcc(y_true, y_pred):
    tp = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    tn = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    fp = K.sum(K.round(K.clip((1 - y_true) * y_pred, 0, 1)))
    fn = K.sum(K.round(K.clip(y_true * (1 - y_pred), 0, 1)))

    num = tp * tn - fp * fn
    den = (tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)
    return num / K.sqrt(den + K.epsilon())

# %%
metrics_c = [tensorflow.keras.metrics.AUC(name="auc_roc",curve="ROC"),tensorflow.keras.metrics.AUC(name="auc_pr",curve="PR"),keras_mcc]

# %%
model.compile(loss='binary_crossentropy', 
              optimizer=tensorflow.keras.optimizers.Adam(learning_rate=0.008), 
              metrics=metrics_c)

# %%
##early_stop = EarlyStopping(monitor='loss',min_delta=0,patience=10, verbose=0,mode='min',restore_best_weights=True)

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_keras_mcc', factor=0.99,patience=20, min_lr=0.005, verbose=1)

# %%
#checkpoint_filepath = 'weights-improvement-{val_auc_roc:.1f}.hdf5'
checkpoint_filepath_1 = 'weights-improvement-val-loss.hdf5'
model_checkpoint_callback_1 = ModelCheckpoint(filepath=checkpoint_filepath_1,save_weights_only=False,monitor='val_loss',mode='min',save_best_only=True)

checkpoint_filepath_2 = 'weights-improvement-val-auc-roc.hdf5'
model_checkpoint_callback_2 = ModelCheckpoint(filepath=checkpoint_filepath_2,save_weights_only=False,monitor='val_auc_roc',mode='max',save_best_only=True)

checkpoint_filepath_3 = 'weights-improvement-val-auc-pr.hdf5'
model_checkpoint_callback_3 = ModelCheckpoint(filepath=checkpoint_filepath_3,save_weights_only=False,monitor='val_auc_pr',mode='max',save_best_only=True)

checkpoint_filepath_4 = 'weights-improvement-val-keras-mcc.hdf5'
model_checkpoint_callback_4 = ModelCheckpoint(filepath=checkpoint_filepath_4,save_weights_only=False,monitor='val_keras_mcc',mode='max',save_best_only=True)

# %%
print('Training', matmat_cdr3b.shape, matmat_pepti.shape, y_train.shape)
print('Evaluation', evalmatmat_cdr3b.shape, evalmatmat_pepti.shape, y_eval.shape)

# %%
# ###fit the keras model 
history=model.fit([matmat_cdr3b,matmat_pepti],y_train,
                  batch_size=1024, epochs=500,
                  verbose=0,
                  validation_data=([evalmatmat_cdr3b,evalmatmat_pepti],y_eval),
                  callbacks=[model_checkpoint_callback_1, model_checkpoint_callback_2, model_checkpoint_callback_3, model_checkpoint_callback_4, reduce_lr ]
                  )
print('done')

# %%
# fit the keras model on the dataset CDR3a, CDR3b, peptide
# history=model.fit([train_cdr3a, train_cdr3b,train_pep],train_Y,
#                   batch_size=1024, epochs=100,
#                   validation_data=([test_cdr3a, test_cdr3b,test_pep],test_Y),
#                   #validation_split=0.1,
#                   #class_weight=class_weights,
#                   #class_weight={0: 0.6, 1: 3.0},
#                   callbacks=[early_stop, model_checkpoint_callback],
#                   verbose=1
#                   )

# %%
#training plots ##Classification
fig = plt.figure(figsize=(15,5))

plt.subplot(1,4,1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Classification Losses")
plt.ylabel("Classification Losses")
plt.xlabel("Epoch")
plt.legend(["Training Classification Loss","Valid Classification Loss"])

plt.subplot(1,4,2)
plt.plot(history.history['auc_pr'])
plt.plot(history.history['val_auc_pr'])
plt.title("Classification AUC PR")
plt.ylabel("Classification AUC PR")
plt.xlabel("Epoch")
plt.legend(["Training AUC PR","Valid AUC PR"])

plt.subplot(1,4,3)
plt.plot(history.history['auc_roc'])
plt.plot(history.history['val_auc_roc'])
plt.title("Classification AUC ROC")
plt.ylabel("Classification AUC ROC")
plt.xlabel("Epoch")
plt.legend(["Training AUC ROC","Valid AUC ROC"])

plt.subplot(1,4,4)
plt.plot(history.history['keras_mcc'])
plt.plot(history.history['val_keras_mcc'])
plt.title("Classification MCC")
plt.ylabel("Classification MCC")
plt.xlabel("Epoch")
plt.legend(["Training MCC","Valid MCC"])

plt.show()

# %%
####model load min loss
model_loaded = '/content/weights-improvement-val-loss.hdf5'
model = tensorflow.keras.models.load_model(model_loaded,compile=False)

y_pred = model.predict([evalmatmat_cdr3b,evalmatmat_pepti])
y_act = y_eval.flatten()
y_pred= y_pred.flatten()
y_pred_c=np.where(y_pred>0.5,1,0)


print(roc_auc_score(y_act, y_pred),average_precision_score(y_act, y_pred),matthews_corrcoef(y_act,y_pred_c),cohen_kappa_score(y_act,y_pred_c))

# %%
####model load max aucroc


model_loaded = '/content/weights-improvement-val-auc-roc.hdf5'
model = tensorflow.keras.models.load_model(model_loaded,compile=False)


y_pred = model.predict([evalmatmat_cdr3b,evalmatmat_pepti])
y_act = y_eval.flatten()
y_pred= y_pred.flatten()
y_pred_c=np.where(y_pred>0.5,1,0)


print(roc_auc_score(y_act, y_pred),average_precision_score(y_act, y_pred),matthews_corrcoef(y_act,y_pred_c),cohen_kappa_score(y_act,y_pred_c))

# %%
####model load max aucpr


model_loaded = '/content/weights-improvement-val-auc-pr.hdf5'
model = tensorflow.keras.models.load_model(model_loaded,compile=False)



y_pred = model.predict([evalmatmat_cdr3b,evalmatmat_pepti])
y_act = y_eval.flatten()
y_pred= y_pred.flatten()
y_pred_c=np.where(y_pred>0.5,1,0)


print(roc_auc_score(y_act, y_pred),average_precision_score(y_act, y_pred),matthews_corrcoef(y_act,y_pred_c),cohen_kappa_score(y_act,y_pred_c))

# %%
####model load max mcc


model_loaded = '/content/weights-improvement-val-keras-mcc.hdf5'
model = tensorflow.keras.models.load_model(model_loaded,compile=False)



y_pred = model.predict([evalmatmat_cdr3b,evalmatmat_pepti])
y_act = y_eval.flatten()
y_pred= y_pred.flatten()
y_pred_c=np.where(y_pred>0.5,1,0)


print(roc_auc_score(y_act, y_pred),average_precision_score(y_act, y_pred),matthews_corrcoef(y_act,y_pred_c),cohen_kappa_score(y_act,y_pred_c))

# %%
confusion_matrix(y_act,y_pred_c )

# %%
print(classification_report(y_act,y_pred_c))

# %%
# print('AUC-ROC', roc_auc_score(y_act, y_pred))
# print('AUC-PR',  average_precision_score(y_act, y_pred))

# print('MCC', matthews_corrcoef(y_act,y_pred_c))
# print('CKS', cohen_kappa_score(y_act,y_pred_c))

# %%
print(roc_auc_score(y_act, y_pred),average_precision_score(y_act, y_pred),matthews_corrcoef(y_act,y_pred_c),cohen_kappa_score(y_act,y_pred_c))

# %%
#### peptide wise



pep_list = [ 'GILGFVFTL', 'GLCTLVAML']

for i in range(2):
  pep_f = pep_list[i]

  y_pred_pep = y_pred_c[df_eval['peptide'] == pep_f]

  y_act_pep  = y_act[df_eval['peptide'] == pep_f]

  #y_act_pep.shape, y_pred_pep.shape

  y_act_pw = y_act_pep.flatten()
  y_pred_pw= y_pred_pep.flatten()

  y_pred_pw_c=np.where(y_pred_pw>0.5,1,0)

  print('MCC', pep_f ,matthews_corrcoef(y_act_pw,y_pred_pw_c))

# %%
confusion_matrix(y_act_pw,y_pred_pw_c)

# %%
# print(classification_report(y_act_pw,y_pred_pw_c))

# %%
print('MCC', pep_f ,matthews_corrcoef(y_act_pw,y_pred_pw_c))

# %%
# !rm *.hdf5

# %%
from tensorflow.keras import regularizers

# %%
#### make_model for 10 fold CV

def make_data(orig_matmat_cdr3b, orig_matmat_pepti, orig_y_train, train_ind, test_ind):


  matmat_cdr3b = orig_matmat_cdr3b[train_ind]
  matmat_pepti = orig_matmat_pepti[train_ind]
  y_train      = orig_y_train[train_ind]

  #### internal eval
  evalmatmat_cdr3b = orig_matmat_cdr3b[test_ind]
  evalmatmat_pepti = orig_matmat_pepti[test_ind]
  y_eval           = orig_y_train[test_ind]



  train_input = [matmat_cdr3b,matmat_pepti]
  train_output= y_train


  test_input = [evalmatmat_cdr3b,evalmatmat_pepti]
  test_output= y_eval


  #model
  l2val = 0.001
  dropr = 0.3

  input_1 = Input(shape = (1280,), name='i_1')
  dense1_1 = Dense(32, activation = 'gelu',kernel_regularizer=regularizers.L2(l2val))(input_1)
  bn1_1 = BatchNormalization()(dense1_1)
  drop_1 = Dropout(dropr)(bn1_1)

  #input_2
  input_2 = Input(shape = (1280,), name='i_2')
  dense2_1 = Dense(32, activation = 'gelu',kernel_regularizer=regularizers.L2(l2val))(input_2)
  bn2_1 = BatchNormalization()(dense2_1)
  drop_2 = Dropout(dropr)(bn2_1)


  # concatenate
  ##concat   = Concatenate()([dense1_1, dense2_1])
  ##concat   = Concatenate()([bn1_1, bn2_1])
  concat   = Concatenate()([drop_1,drop_2])
  fc_1   = Dense(32, activation = 'gelu',kernel_regularizer=regularizers.L2(l2val))(concat)
  drop_4 = Dropout(dropr)(fc_1)
  fc_2   = Dense(32, activation = 'gelu')(drop_4)
  #classification output- TCR-Peptide Binding yes/no
  output  = Dense(1, activation = 'sigmoid')(fc_2)

  # create model with two inputs
  model = Model(inputs=[input_1,input_2], outputs=output)

  return model, train_input, test_input, train_output, test_output

# %%
#### 10 Fold CV

from sklearn.model_selection import KFold
# Define the K-fold Cross Validator
kfold = KFold(n_splits=5, shuffle=True)

# K-fold Cross Validation model evaluation
fold_no = 1

for train_ind, test_ind in kfold.split(orig_matmat_cdr3b):
  clear_sess()
  #print('------------------------------------------------------------------------')
  #print(f'Training for fold {fold_no} ...')
  #print('Train shape',train_ind.shape, 'Test shape',test_ind.shape)

  model, train_input, test_input, train_output, test_output = make_data(orig_matmat_cdr3b, orig_matmat_pepti, orig_y_train, train_ind, test_ind)

  #print('Training', train_input[0].shape, train_input[1].shape, train_input[2].shape, train_output.shape)
  #print('Evaluation', test_input[0].shape, test_input[1].shape, test_input[2].shape, test_output.shape)

  #print(train_inputs[0].shape)
  metrics_c = [tensorflow.keras.metrics.AUC(name="auc_pr",curve="PR"),tensorflow.keras.metrics.AUC(name="auc_roc",curve="ROC"),keras_mcc]
  model.compile(loss="binary_crossentropy", optimizer=Adam(learning_rate=0.0001), metrics=metrics_c )
  #early_stop = EarlyStopping(monitor='loss',min_delta=0,patience=10, verbose=0,mode='min',restore_best_weights=True)
  checkpoint_filepath = f'weights-improvement-{fold_no}.hdf5'
  model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath,save_weights_only=False,monitor='val_keras_mcc',mode='max',save_best_only=True)


  history = model.fit(train_input, train_output,epochs=300,batch_size=1024, verbose=0, validation_data=(test_input,test_output),
                  callbacks=[model_checkpoint_callback])

  model_loaded = f'weights-improvement-{fold_no}.hdf5'
  model = tensorflow.keras.models.load_model(model_loaded,compile=False)

  y_pred = model.predict(test_input, verbose=0)
  y_act = test_output.flatten()
  y_pred= y_pred.flatten()
  y_pred_c=np.where(y_pred>0.5,1,0)
  print(#roc_auc_score(y_act, y_pred),average_precision_score(y_act, y_pred),
        matthews_corrcoef(y_act,y_pred_c)#,cohen_kappa_score(y_act,y_pred_c)
        )
  fold_no = fold_no + 1
