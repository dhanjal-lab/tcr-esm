# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
##### get data
# !cp -r /content/drive/MyDrive/TCR-pMHC-results/ergo_model/* /content/
# Out:
# cp: cannot open '/content/drive/MyDrive/TCR-pMHC-results/ergo_model/ERGO web template maker.gsheet' for reading: Operation not supported

# %%
# !cp -r /content/Samples /content/drive/MyDrive/TCR-pMHC-results/ergo_model/ one time move

# %%
###### extract data
# !unzip -q /content/Samples.zip -d /content/

# %%
###### install pytorch lightning
# !pip install -q pytorch-lightning
# Out:
#      |████████████████████████████████| 800 kB 8.1 MB/s
#      |████████████████████████████████| 512 kB 70.3 MB/s
#      |████████████████████████████████| 125 kB 78.4 MB/s

# %%
#!python Trainer.py 1 0 mcpas AE
#!python Trainer.py 1 0 vdjdb AE

# !python Trainer.py 1 0 vdjdb AE
####!python Trainer.py 1 0 vdjdb10x AE  #set lr=1e-4 and wd 1e-6 for Beta only models
# Out:
#               tcra  ... sign
# 0     CAVENYGQNFVF  ...    0
# 1   CAAGGSGGYQKVTF  ...    0
# 2  CALSELGGATNKLIF  ...    0
# 3   CAASHTNTGNQFYF  ...    1
# 4              UNK  ...    0
#
# [5 rows x 11 columns]
# ####################
#   tcra  ... sign
# 0  UNK  ...    1
# 1  UNK  ...    1
# 2  UNK  ...    1
# 3  UNK  ...    1
# 4  UNK  ...    1
#
# [5 rows x 11 columns]
# Train Total:  209316 pos:  34886 neg:  174430
# Test Total:  152389 pos:  152389 neg:  0
# Missing logger folder: /content/lightning_logs
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ...

# %%
#!python Trainer.py 1 0 mcpas LSTM
# !python Trainer.py 1 0 vdjdb LSTM
##!python Trainer.py 1 0 vdjdb10x LSTM #set lr=1e-4 and wd 1e-6 for Beta only models
# Out:
#               tcra  ... sign
# 0     CAVENYGQNFVF  ...    0
# 1   CAAGGSGGYQKVTF  ...    0
# 2  CALSELGGATNKLIF  ...    0
# 3   CAASHTNTGNQFYF  ...    1
# 4              UNK  ...    0
#
# [5 rows x 11 columns]
# ####################
#   tcra  ... sign
# 0  UNK  ...    1
# 1  UNK  ...    1
# 2  UNK  ...    1
# 3  UNK  ...    1
# 4  UNK  ...    1
#
# [5 rows x 11 columns]
# Train Total:  209316 pos:  34886 neg:  174430
# Test Total:  152389 pos:  152389 neg:  0
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !python Trainer.py 1 0 vdjdb10x AE

# %%
# !python Trainer.py 1 0 vdjdb10x LSTM
