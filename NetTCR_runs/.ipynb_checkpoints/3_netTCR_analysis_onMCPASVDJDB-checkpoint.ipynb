# %%
import pandas as pd
import numpy as np
from sklearn.metrics import *


import tensorflow
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


from sklearn.model_selection import train_test_split

from collections import Counter

import os, sys
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv1D, GlobalMaxPooling1D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import glorot_normal
from tensorflow.keras.activations import sigmoid
from sklearn.metrics import roc_auc_score
import utils
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import EarlyStopping

from nettcr_architectures import nettcr_ab, nettcr_one_chain

# %%
# ### load data

# train_data= pd.read_csv('2_VDJDB_final_datasets/1_origVDJDB_NoMHC/2_origVDJDB_NoMHC_train_B.csv')

# test_data = pd.read_csv('2_VDJDB_final_datasets/1_origVDJDB_NoMHC/5_origVDJDB_NoMHC_test_B.csv')




#### ext test data

train_data = pd.read_csv('4_NETTCR_final_dataset/train_beta_99.csv')

test_data = pd.read_csv('PMTnet_test6190_set1.csv')

# %%
train_data
# Out:
#                     CDR3b    peptide  partition  binder
# 0          ASRPGLMGGRPEQY  LLFGYPVYV          5       1
# 1             ASSAGLFPEQF  LLFGYPVYV          5       1
# 2      ASSQVSGLAGGQNTGELF  GLCTLVAML          5       1
# 3        ASSQDGLAGGAFNEQF  GLCTLVAML          5       1
# 4        ASSLVKLGIALIETQY  GLCTLVAML          5       1
# ...                   ...        ...        ...     ...
# 55219    ASIRGTSGASGQETQY  LLFGYPVYV          5       0
# 55220        ASSLRGRGEGYT  LLFGYPVYV          5       0
# 55221        SAPGTGNQETQY  LLFGYPVYV          5       0
# 55222       SVEASGRGDNEQF  LLFGYPVYV          5       0
# 55223     ASSVHKAETNTGELF  LLFGYPVYV          5       0
#
# [55224 rows x 4 columns]

# %%
test_data
# Out:
#                 tcrb     peptide  sign
# 0      CASSLSFGTEAFF  SMLGIGIYPV     1
# 1      CASSLSFGTEAFF  LMFDRGMSLL     1
# 2      CASSLSFGTEAFF  ILEDRGFNQV     1
# 3      CASSLSFGTEAFF  MMWDRGLGMM     1
# 4      CASSLSFGTEAFF  NLSNLGILPV     1
# ...              ...         ...   ...
# 6185  CVSSVDKGGTDTQY   SLFNTVACL     0
# 6186  CVSSVDKGGTDTQY   SLFWTVATL     0
# 6187  CVSSVDKGGTDTQY   SLPNTVATL     0
# 6188  CVSSVDKGGTDTQY   SLYNTIATL     0
# 6189  CVSSVDKGGTDTQY  YLGGPDFPTI     0
#
# [6190 rows x 3 columns]

# %%
train_data.shape, test_data.shape
# Out:
# ((55224, 4), (6190, 3))

# %%
max([len(item) for item in test_data.tcrb.values.tolist()]), max([len(item) for item in test_data.peptide.values.tolist()]),
# Out:
# (22, 13)

# %%
chain = "b"#["a","b","ab"]

# %%
# # train_data = data_train#pd.read_csv(args.trainfile)
# # test_data = data_test#pd.read_csv(args.testfile) might not be useful here

# train_data = sample_train
# test_data = sample_test

# %%
# Encode data
encoding = utils.blosum50_20aa
early_stop = EarlyStopping(monitor='loss',min_delta=0,patience=10, verbose=0,mode='min',restore_best_weights=True)

# %%
def clear_sess():
  try:
    del model 
    del history
  except:
    pass
  from tensorflow.keras import backend as K
  K.clear_session()
  import gc
  gc.collect()
  return None

# %%
clear_sess()

# %%
# split_seed = 2

# %%
# Call and compile the model ### test not needed-checking cross validation
if chain=='ab':
    pep_train  = utils.enc_list_bl_max_len(train_data.peptide, encoding, 25)
    tcra_train = utils.enc_list_bl_max_len(train_data.tcra, encoding, 30)
    tcrb_train = utils.enc_list_bl_max_len(train_data.tcrb, encoding, 30)
    y_train    = np.array(train_data.sign).reshape(-1,1)

#     pep_test   = utils.enc_list_bl_max_len(test_data.peptide, encoding, 25)
#     tcra_test  = utils.enc_list_bl_max_len(test_data.tcra, encoding, 30)
#     tcrb_test  = utils.enc_list_bl_max_len(test_data.tcrb, encoding, 30)
#     y_test     = np.array(test_data.sign).reshape(-1,1)
    
    ##### test_train_split not needed for CV
   
    
    tcra_train, tcra_test, tcrb_train, tcrb_test, pep_train, pep_test, y_train, y_test =  train_test_split(tcra_train, tcrb_train, pep_train, y_train, test_size=0.20, random_state=split_seed)
    ##### 
    
    train_inputs = [tcra_train, tcrb_train, pep_train]
    test_inputs  = [tcra_test, tcrb_test, pep_test]
    
    print(tcra_train.shape, tcra_test.shape, tcrb_train.shape, tcrb_test.shape, pep_train.shape, pep_test.shape, y_train.shape, y_test.shape)

    model = nettcr_ab()
    
elif chain=="a":
    pep_train  = utils.enc_list_bl_max_len(train_data.peptide, encoding, 25)
    tcra_train = utils.enc_list_bl_max_len(train_data.tcra, encoding, 30)
    y_train    = np.array(train_data.sign).reshape(-1,1)

#     pep_test   = utils.enc_list_bl_max_len(test_data.peptide, encoding, 25)
#     tcra_test  = utils.enc_list_bl_max_len(test_data.tcra, encoding, 30)
#     y_test     = np.array(test_data.sign).reshape(-1,1)
    
    ##### test_train_split not needed for CV
    
    tcra_train, tcra_test, pep_train, pep_test, y_train, y_test =  train_test_split(tcra_train, pep_train, y_train, test_size=0.20, random_state=split_seed)
    
    
    train_inputs = [tcra_train, pep_train]
    test_inputs = [tcra_test, pep_test]
                                                                                    
    print(tcra_train.shape, tcra_test.shape, pep_train.shape, pep_test.shape, y_train.shape, y_test.shape)                                                                         
                                                                                    
                                                                                    
    model = nettcr_one_chain()
    
    
elif chain=="b":
    pep_train  = utils.enc_list_bl_max_len(train_data.peptide, encoding, 25)
    tcrb_train = utils.enc_list_bl_max_len(train_data.CDR3b, encoding, 30)
    y_train    = np.array(train_data.binder).reshape(-1,1)

    pep_test   = utils.enc_list_bl_max_len(test_data.peptide, encoding, 25)
    tcrb_test  = utils.enc_list_bl_max_len(test_data.tcrb, encoding, 30)
    y_test     = np.array(test_data.sign).reshape(-1,1)
    
    ##### test_train_split not needed for CV
    
    #tcrb_train, tcrb_test, pep_train, pep_test, y_train, y_test =  train_test_split(tcrb_train, pep_train, y_train, test_size=0.20, random_state=split_seed)

    
    train_inputs = [tcrb_train, pep_train]
    test_inputs = [tcrb_test, pep_test]
                                                                                    
                                                                                    
    print(tcrb_train.shape, tcrb_test.shape, pep_train.shape, pep_test.shape, y_train.shape, y_test.shape)                                                                                
                                                                                    
                                                                                    
                                                                                    
    model = nettcr_one_chain()
# Out:
# Unknown amino acid in peptides:  , encoding aborted!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
# mdl.summary()

# %%
metrics_c = [#'accuracy',
    #keras.metrics.FalseNegatives(name="fn"),
    #keras.metrics.FalsePositives(name="fp"),
    #keras.metrics.TrueNegatives(name="tn"),
    #keras.metrics.TruePositives(name="tp"),
    #keras.metrics.BinaryAccuracy(name='accuracy'),
    #tensorflow.keras.metrics.Precision(name="precision"),
    #tensorflow.keras.metrics.Recall(name="recall"),
    tensorflow.keras.metrics.AUC(name="auc_pr",curve="PR"),
    tensorflow.keras.metrics.AUC(name="auc_roc",curve="ROC")
]

# %%
model.compile(loss="binary_crossentropy", optimizer=Adam(learning_rate=0.001), metrics=metrics_c )

# %%
early_stop = EarlyStopping(monitor='loss',min_delta=0,
               patience=10, verbose=0,mode='min',restore_best_weights=True)

# %%
checkpoint_filepath = 'weights-improvement.hdf5'
model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath,save_weights_only=False,monitor='val_auc_roc',mode='max',save_best_only=True)

# %%
history = model.fit(train_inputs, y_train,epochs=100,batch_size=32, verbose=1, 
                  #validation_split=0.2, 
                  validation_data=([test_inputs],y_test),
                  callbacks=[early_stop,
                             model_checkpoint_callback
                            ])
print('done')
# Out:
# Epoch 1/100
# 585/585 [==============================] - 6s 8ms/step - loss: 0.4081 - auc_pr: 0.2813 - auc_roc: 0.7177 - val_loss: 0.3958 - val_auc_pr: 0.3230 - val_auc_roc: 0.7738
# Epoch 2/100
# 585/585 [==============================] - 5s 8ms/step - loss: 0.3712 - auc_pr: 0.3175 - auc_roc: 0.7698 - val_loss: 0.3773 - val_auc_pr: 0.3122 - val_auc_roc: 0.7797
# Epoch 3/100
# 585/585 [==============================] - 5s 8ms/step - loss: 0.3599 - auc_pr: 0.3299 - auc_roc: 0.7860 - val_loss: 0.3586 - val_auc_pr: 0.3195 - val_auc_roc: 0.7874
# Epoch 4/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.3521 - auc_pr: 0.3440 - auc_roc: 0.7953 - val_loss: 0.3525 - val_auc_pr: 0.3351 - val_auc_roc: 0.7986
# Epoch 5/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.3411 - auc_pr: 0.3903 - auc_roc: 0.8106 - val_loss: 0.3425 - val_auc_pr: 0.4201 - val_auc_roc: 0.8133
# Epoch 6/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.3292 - auc_pr: 0.4277 - auc_roc: 0.8249 - val_loss: 0.3314 - val_auc_pr: 0.4387 - val_auc_roc: 0.8266
# Epoch 7/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.3188 - auc_pr: 0.4561 - auc_roc: 0.8363 - val_loss: 0.3234 - val_auc_pr: 0.4808 - val_auc_roc: 0.8406
# Epoch 8/100
# 585/585 [==============================] - 5s 8ms/step - loss: 0.3048 - auc_pr: 0.5126 - auc_roc: 0.8695 - val_loss: 0.3106 - val_auc_pr: 0.5188 - val_auc_roc: 0.8688
# Epoch 9/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.2844 - auc_pr: 0.5625 - auc_roc: 0.8967 - val_loss: 0.2928 - val_auc_pr: 0.5596 - val_auc_roc: 0.8906
# Epoch 10/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.2679 - auc_pr: 0.5988 - auc_roc: 0.9101 - val_loss: 0.2830 - val_auc_pr: 0.5691 - val_auc_roc: 0.8978
# Epoch 11/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.2568 - auc_pr: 0.6134 - auc_roc: 0.9174 - val_loss: 0.2703 - val_auc_pr: 0.5879 - val_auc_roc: 0.9066
# Epoch 12/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.2459 - auc_pr: 0.6392 - auc_roc: 0.9255 - val_loss: 0.2726 - val_auc_pr: 0.5961 - val_auc_roc: 0.9088
# Epoch 13/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.2400 - auc_pr: 0.6478 - auc_roc: 0.9283 - val_loss: 0.2648 - val_auc_pr: 0.5995 - val_auc_roc: 0.9107
# Epoch 14/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.2343 - auc_pr: 0.6590 - auc_roc: 0.9325 - val_loss: 0.2691 - val_auc_pr: 0.5980 - val_auc_roc: 0.9104
# Epoch 15/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.2260 - auc_pr: 0.6796 - auc_roc: 0.9376 - val_loss: 0.2621 - val_auc_pr: 0.5987 - val_auc_roc: 0.9126
# Epoch 16/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.2217 - auc_pr: 0.6838 - auc_roc: 0.9397 - val_loss: 0.2759 - val_auc_pr: 0.6091 - val_auc_roc: 0.9114
# Epoch 17/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.2193 - auc_pr: 0.6855 - auc_roc: 0.9410 - val_loss: 0.2734 - val_auc_pr: 0.5987 - val_auc_roc: 0.9093
# Epoch 18/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.2129 - auc_pr: 0.7018 - auc_roc: 0.9450 - val_loss: 0.2684 - val_auc_pr: 0.6040 - val_auc_roc: 0.9151
# Epoch 19/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.2085 - auc_pr: 0.7097 - auc_roc: 0.9473 - val_loss: 0.2700 - val_auc_pr: 0.6033 - val_auc_roc: 0.9151
# Epoch 20/100
# 585/585 [==============================] - 4s 6ms/step - loss: 0.2090 - auc_pr: 0.7068 - auc_roc: 0.9467 - val_loss: 0.2840 - val_auc_pr: 0.5956 - val_auc_roc: 0.9120
# Epoch 21/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.2027 - auc_pr: 0.7213 - auc_roc: 0.9501 - val_loss: 0.2620 - val_auc_pr: 0.6062 - val_auc_roc: 0.9165
# Epoch 22/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1978 - auc_pr: 0.7342 - auc_roc: 0.9527 - val_loss: 0.2715 - val_auc_pr: 0.6063 - val_auc_roc: 0.9154
# Epoch 23/100
# 585/585 [==============================] - 4s 6ms/step - loss: 0.1933 - auc_pr: 0.7413 - auc_roc: 0.9549 - val_loss: 0.3064 - val_auc_pr: 0.6043 - val_auc_roc: 0.9115
# Epoch 24/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1927 - auc_pr: 0.7420 - auc_roc: 0.9549 - val_loss: 0.2671 - val_auc_pr: 0.6095 - val_auc_roc: 0.9139
# Epoch 25/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1902 - auc_pr: 0.7487 - auc_roc: 0.9566 - val_loss: 0.2621 - val_auc_pr: 0.6168 - val_auc_roc: 0.9192
# Epoch 26/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1864 - auc_pr: 0.7581 - auc_roc: 0.9583 - val_loss: 0.2796 - val_auc_pr: 0.6108 - val_auc_roc: 0.9158
# Epoch 27/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1828 - auc_pr: 0.7663 - auc_roc: 0.9603 - val_loss: 0.2764 - val_auc_pr: 0.6119 - val_auc_roc: 0.9169
# Epoch 28/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1804 - auc_pr: 0.7732 - auc_roc: 0.9614 - val_loss: 0.2648 - val_auc_pr: 0.6033 - val_auc_roc: 0.9187
# Epoch 29/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1772 - auc_pr: 0.7796 - auc_roc: 0.9630 - val_loss: 0.2754 - val_auc_pr: 0.6129 - val_auc_roc: 0.9166
# Epoch 30/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1760 - auc_pr: 0.7853 - auc_roc: 0.9639 - val_loss: 0.2803 - val_auc_pr: 0.6178 - val_auc_roc: 0.9144
# Epoch 31/100
# 585/585 [==============================] - 4s 8ms/step - loss: 0.1711 - auc_pr: 0.7910 - auc_roc: 0.9654 - val_loss: 0.2729 - val_auc_pr: 0.6091 - val_auc_roc: 0.9180
# Epoch 32/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1704 - auc_pr: 0.8005 - auc_roc: 0.9660 - val_loss: 0.2807 - val_auc_pr: 0.6270 - val_auc_roc: 0.9194
# Epoch 33/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1659 - auc_pr: 0.8041 - auc_roc: 0.9673 - val_loss: 0.2771 - val_auc_pr: 0.6158 - val_auc_roc: 0.9177
# Epoch 34/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1647 - auc_pr: 0.8127 - auc_roc: 0.9685 - val_loss: 0.2850 - val_auc_pr: 0.6071 - val_auc_roc: 0.9141
# Epoch 35/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1609 - auc_pr: 0.8191 - auc_roc: 0.9700 - val_loss: 0.2887 - val_auc_pr: 0.5983 - val_auc_roc: 0.9122
# Epoch 36/100
# 585/585 [==============================] - 5s 8ms/step - loss: 0.1582 - auc_pr: 0.8212 - auc_roc: 0.9709 - val_loss: 0.2990 - val_auc_pr: 0.6012 - val_auc_roc: 0.9101
# Epoch 37/100
# 585/585 [==============================] - 5s 8ms/step - loss: 0.1580 - auc_pr: 0.8262 - auc_roc: 0.9709 - val_loss: 0.2949 - val_auc_pr: 0.6359 - val_auc_roc: 0.9160
# Epoch 38/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1556 - auc_pr: 0.8308 - auc_roc: 0.9721 - val_loss: 0.2934 - val_auc_pr: 0.6149 - val_auc_roc: 0.9154
# Epoch 39/100
# 585/585 [==============================] - 4s 6ms/step - loss: 0.1529 - auc_pr: 0.8408 - auc_roc: 0.9731 - val_loss: 0.2895 - val_auc_pr: 0.6221 - val_auc_roc: 0.9173
# Epoch 40/100
# 585/585 [==============================] - 4s 8ms/step - loss: 0.1536 - auc_pr: 0.8333 - auc_roc: 0.9727 - val_loss: 0.3017 - val_auc_pr: 0.6094 - val_auc_roc: 0.9076
# Epoch 41/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1463 - auc_pr: 0.8542 - auc_roc: 0.9754 - val_loss: 0.3358 - val_auc_pr: 0.6003 - val_auc_roc: 0.8994
# Epoch 42/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1450 - auc_pr: 0.8542 - auc_roc: 0.9754 - val_loss: 0.3019 - val_auc_pr: 0.6059 - val_auc_roc: 0.9091
# Epoch 43/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1436 - auc_pr: 0.8535 - auc_roc: 0.9761 - val_loss: 0.3043 - val_auc_pr: 0.6212 - val_auc_roc: 0.9127
# Epoch 44/100
# 585/585 [==============================] - 5s 8ms/step - loss: 0.1457 - auc_pr: 0.8465 - auc_roc: 0.9753 - val_loss: 0.2974 - val_auc_pr: 0.6147 - val_auc_roc: 0.9129
# Epoch 45/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1403 - auc_pr: 0.8631 - auc_roc: 0.9773 - val_loss: 0.3069 - val_auc_pr: 0.6080 - val_auc_roc: 0.9122
# Epoch 46/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1429 - auc_pr: 0.8547 - auc_roc: 0.9763 - val_loss: 0.3027 - val_auc_pr: 0.6136 - val_auc_roc: 0.9128
# Epoch 47/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1351 - auc_pr: 0.8724 - auc_roc: 0.9787 - val_loss: 0.3101 - val_auc_pr: 0.6051 - val_auc_roc: 0.9062
# Epoch 48/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1350 - auc_pr: 0.8733 - auc_roc: 0.9789 - val_loss: 0.3260 - val_auc_pr: 0.5969 - val_auc_roc: 0.9035
# Epoch 49/100
# 585/585 [==============================] - 5s 8ms/step - loss: 0.1331 - auc_pr: 0.8787 - auc_roc: 0.9798 - val_loss: 0.3186 - val_auc_pr: 0.6003 - val_auc_roc: 0.9057
# Epoch 50/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1303 - auc_pr: 0.8805 - auc_roc: 0.9803 - val_loss: 0.3206 - val_auc_pr: 0.6010 - val_auc_roc: 0.9041
# Epoch 51/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1311 - auc_pr: 0.8793 - auc_roc: 0.9799 - val_loss: 0.3327 - val_auc_pr: 0.5941 - val_auc_roc: 0.9002
# Epoch 52/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1309 - auc_pr: 0.8839 - auc_roc: 0.9805 - val_loss: 0.3281 - val_auc_pr: 0.6112 - val_auc_roc: 0.9035
# Epoch 53/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1308 - auc_pr: 0.8853 - auc_roc: 0.9803 - val_loss: 0.3159 - val_auc_pr: 0.6000 - val_auc_roc: 0.9070
# Epoch 54/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1264 - auc_pr: 0.8909 - auc_roc: 0.9818 - val_loss: 0.3293 - val_auc_pr: 0.5992 - val_auc_roc: 0.9038
# Epoch 55/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1245 - auc_pr: 0.8979 - auc_roc: 0.9822 - val_loss: 0.3383 - val_auc_pr: 0.5908 - val_auc_roc: 0.8988
# Epoch 56/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1232 - auc_pr: 0.8973 - auc_roc: 0.9825 - val_loss: 0.3721 - val_auc_pr: 0.5886 - val_auc_roc: 0.8899
# Epoch 57/100
# 585/585 [==============================] - 4s 6ms/step - loss: 0.1222 - auc_pr: 0.9029 - auc_roc: 0.9832 - val_loss: 0.3325 - val_auc_pr: 0.5951 - val_auc_roc: 0.9025
# Epoch 58/100
# 585/585 [==============================] - 4s 6ms/step - loss: 0.1208 - auc_pr: 0.9051 - auc_roc: 0.9834 - val_loss: 0.3324 - val_auc_pr: 0.6079 - val_auc_roc: 0.9057
# Epoch 59/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1186 - auc_pr: 0.9067 - auc_roc: 0.9840 - val_loss: 0.3451 - val_auc_pr: 0.5890 - val_auc_roc: 0.8952
# Epoch 60/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1179 - auc_pr: 0.9097 - auc_roc: 0.9844 - val_loss: 0.3473 - val_auc_pr: 0.5925 - val_auc_roc: 0.8978
# Epoch 61/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1180 - auc_pr: 0.9086 - auc_roc: 0.9841 - val_loss: 0.3516 - val_auc_pr: 0.5992 - val_auc_roc: 0.8970
# Epoch 62/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1185 - auc_pr: 0.9098 - auc_roc: 0.9840 - val_loss: 0.3616 - val_auc_pr: 0.5869 - val_auc_roc: 0.8915
# Epoch 63/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1157 - auc_pr: 0.9124 - auc_roc: 0.9847 - val_loss: 0.3541 - val_auc_pr: 0.5842 - val_auc_roc: 0.8954
# Epoch 64/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1125 - auc_pr: 0.9181 - auc_roc: 0.9855 - val_loss: 0.3490 - val_auc_pr: 0.5960 - val_auc_roc: 0.9009
# Epoch 65/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1160 - auc_pr: 0.9124 - auc_roc: 0.9847 - val_loss: 0.3621 - val_auc_pr: 0.5829 - val_auc_roc: 0.8937
# Epoch 66/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1132 - auc_pr: 0.9212 - auc_roc: 0.9857 - val_loss: 0.3568 - val_auc_pr: 0.6038 - val_auc_roc: 0.8976
# Epoch 67/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1098 - auc_pr: 0.9225 - auc_roc: 0.9864 - val_loss: 0.3725 - val_auc_pr: 0.5813 - val_auc_roc: 0.8898
# Epoch 68/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1098 - auc_pr: 0.9240 - auc_roc: 0.9864 - val_loss: 0.3668 - val_auc_pr: 0.5911 - val_auc_roc: 0.8903
# Epoch 69/100
# 585/585 [==============================] - 4s 6ms/step - loss: 0.1103 - auc_pr: 0.9220 - auc_roc: 0.9862 - val_loss: 0.3717 - val_auc_pr: 0.5871 - val_auc_roc: 0.8923
# Epoch 70/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1078 - auc_pr: 0.9222 - auc_roc: 0.9868 - val_loss: 0.3784 - val_auc_pr: 0.5839 - val_auc_roc: 0.8887
# Epoch 71/100
# 585/585 [==============================] - 4s 6ms/step - loss: 0.1091 - auc_pr: 0.9245 - auc_roc: 0.9865 - val_loss: 0.3698 - val_auc_pr: 0.5913 - val_auc_roc: 0.8992
# Epoch 72/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1052 - auc_pr: 0.9331 - auc_roc: 0.9876 - val_loss: 0.3771 - val_auc_pr: 0.5904 - val_auc_roc: 0.8933
# Epoch 73/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1045 - auc_pr: 0.9331 - auc_roc: 0.9878 - val_loss: 0.3689 - val_auc_pr: 0.5953 - val_auc_roc: 0.8987
# Epoch 74/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1060 - auc_pr: 0.9288 - auc_roc: 0.9873 - val_loss: 0.3781 - val_auc_pr: 0.5939 - val_auc_roc: 0.8907
# Epoch 75/100
# 585/585 [==============================] - 4s 6ms/step - loss: 0.1082 - auc_pr: 0.9285 - auc_roc: 0.9867 - val_loss: 0.3722 - val_auc_pr: 0.6065 - val_auc_roc: 0.8979
# Epoch 76/100
# 585/585 [==============================] - 4s 6ms/step - loss: 0.1020 - auc_pr: 0.9377 - auc_roc: 0.9883 - val_loss: 0.3816 - val_auc_pr: 0.5935 - val_auc_roc: 0.8914
# Epoch 77/100
# 585/585 [==============================] - 4s 6ms/step - loss: 0.1006 - auc_pr: 0.9394 - auc_roc: 0.9887 - val_loss: 0.3851 - val_auc_pr: 0.5843 - val_auc_roc: 0.8906
# Epoch 78/100
# 585/585 [==============================] - 4s 6ms/step - loss: 0.0998 - auc_pr: 0.9391 - auc_roc: 0.9888 - val_loss: 0.3887 - val_auc_pr: 0.5767 - val_auc_roc: 0.8938
# Epoch 79/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.1025 - auc_pr: 0.9355 - auc_roc: 0.9880 - val_loss: 0.3918 - val_auc_pr: 0.5729 - val_auc_roc: 0.8876
# Epoch 80/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.0992 - auc_pr: 0.9403 - auc_roc: 0.9888 - val_loss: 0.4008 - val_auc_pr: 0.5733 - val_auc_roc: 0.8869
# Epoch 81/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.0981 - auc_pr: 0.9416 - auc_roc: 0.9893 - val_loss: 0.4120 - val_auc_pr: 0.5733 - val_auc_roc: 0.8818
# Epoch 82/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.0989 - auc_pr: 0.9396 - auc_roc: 0.9889 - val_loss: 0.3960 - val_auc_pr: 0.5858 - val_auc_roc: 0.8909
# Epoch 83/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.0956 - auc_pr: 0.9464 - auc_roc: 0.9899 - val_loss: 0.4206 - val_auc_pr: 0.5827 - val_auc_roc: 0.8804
# Epoch 84/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.0998 - auc_pr: 0.9417 - auc_roc: 0.9888 - val_loss: 0.4013 - val_auc_pr: 0.5789 - val_auc_roc: 0.8907
# Epoch 85/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.0970 - auc_pr: 0.9434 - auc_roc: 0.9894 - val_loss: 0.4130 - val_auc_pr: 0.5817 - val_auc_roc: 0.8865
# Epoch 86/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.0956 - auc_pr: 0.9438 - auc_roc: 0.9897 - val_loss: 0.4001 - val_auc_pr: 0.5734 - val_auc_roc: 0.8851
# Epoch 87/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.0937 - auc_pr: 0.9471 - auc_roc: 0.9902 - val_loss: 0.4126 - val_auc_pr: 0.5737 - val_auc_roc: 0.8842
# Epoch 88/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.0939 - auc_pr: 0.9482 - auc_roc: 0.9902 - val_loss: 0.4090 - val_auc_pr: 0.5821 - val_auc_roc: 0.8898
# Epoch 89/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.0941 - auc_pr: 0.9448 - auc_roc: 0.9900 - val_loss: 0.4400 - val_auc_pr: 0.5707 - val_auc_roc: 0.8742
# Epoch 90/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.0951 - auc_pr: 0.9460 - auc_roc: 0.9897 - val_loss: 0.4035 - val_auc_pr: 0.5836 - val_auc_roc: 0.8930
# Epoch 91/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.0923 - auc_pr: 0.9484 - auc_roc: 0.9904 - val_loss: 0.4355 - val_auc_pr: 0.5716 - val_auc_roc: 0.8801
# Epoch 92/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.0929 - auc_pr: 0.9497 - auc_roc: 0.9904 - val_loss: 0.4182 - val_auc_pr: 0.5756 - val_auc_roc: 0.8853
# Epoch 93/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.0916 - auc_pr: 0.9509 - auc_roc: 0.9906 - val_loss: 0.4184 - val_auc_pr: 0.5870 - val_auc_roc: 0.8860
# Epoch 94/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.0921 - auc_pr: 0.9489 - auc_roc: 0.9904 - val_loss: 0.4171 - val_auc_pr: 0.5853 - val_auc_roc: 0.8872
# Epoch 95/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.0905 - auc_pr: 0.9516 - auc_roc: 0.9909 - val_loss: 0.4142 - val_auc_pr: 0.5795 - val_auc_roc: 0.8872
# Epoch 96/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.0888 - auc_pr: 0.9529 - auc_roc: 0.9912 - val_loss: 0.4182 - val_auc_pr: 0.5736 - val_auc_roc: 0.8857
# Epoch 97/100
# 585/585 [==============================] - 4s 6ms/step - loss: 0.0891 - auc_pr: 0.9529 - auc_roc: 0.9911 - val_loss: 0.4363 - val_auc_pr: 0.5767 - val_auc_roc: 0.8760
# Epoch 98/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.0916 - auc_pr: 0.9489 - auc_roc: 0.9905 - val_loss: 0.4475 - val_auc_pr: 0.5759 - val_auc_roc: 0.8764
# Epoch 99/100
# 585/585 [==============================] - 4s 7ms/step - loss: 0.0889 - auc_pr: 0.9530 - auc_roc: 0.9912 - val_loss: 0.4359 - val_auc_pr: 0.5777 - val_auc_roc: 0.8832
# Epoch 100/100
# 585/585 [==============================] - 4s 6ms/step - loss: 0.0888 - auc_pr: 0.9536 - auc_roc: 0.9912 - val_loss: 0.4785 - val_auc_pr: 0.5480 - val_auc_roc: 0.8650
# done

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# %matplotlib inline

# %%
#@title Classification Hidden
#training plots ##Classification
fig = plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Classification Losses")
plt.ylabel("Classification Losses")
plt.xlabel("Epoch")
plt.legend(["Training Classification Loss","Valid Classification Loss"])

plt.subplot(1,3,2)
plt.plot(history.history['auc_pr'])
plt.plot(history.history['val_auc_pr'])
plt.title("Classification AUC PR")
plt.ylabel("Classification AUC PR")
plt.xlabel("Epoch")
plt.legend(["Training AUC PR","Valid AUC PR"])

plt.subplot(1,3,3)
plt.plot(history.history['auc_roc'])
plt.plot(history.history['val_auc_roc'])
plt.title("Classification AUC ROC")
plt.ylabel("Classification AUC ROC")
plt.xlabel("Epoch")
plt.legend(["Training AUC ROC","Valid AUC ROC"])

plt.show()

# %%
####model load
#model_loaded = 'weights-improvement-0.6.hdf5'
model_loaded = 'weights-improvement.hdf5'
model = tensorflow.keras.models.load_model(model_loaded,compile=True)

# %%
y_pred = model.predict([test_inputs])

# %%
y_act = y_test.flatten()

# %%
y_pred= y_pred.flatten()

# %%
y_pred_c=np.where(y_pred>0.5,1,0)

# %%
confusion_matrix(y_act,y_pred_c )
# Out:
# array([[3488,  403],
#        [ 207,  575]])

# %%
print(classification_report(y_act,y_pred_c))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.90      0.92      3891
#            1       0.59      0.74      0.65       782
#
#     accuracy                           0.87      4673
#    macro avg       0.77      0.82      0.79      4673
# weighted avg       0.88      0.87      0.88      4673

# %%
print('AUC-ROC', roc_auc_score(y_act, y_pred))
print('AUC-PR',  average_precision_score(y_act, y_pred))

print('MCC', matthews_corrcoef(y_act,y_pred_c))
print('CKS', cohen_kappa_score(y_act,y_pred_c))
# Out:
# AUC-ROC 0.921182300817481
# AUC-PR 0.627960967428039
# MCC 0.5796731538409293
# CKS 0.574222899621323

# %%
print(roc_auc_score(y_act, y_pred),average_precision_score(y_act, y_pred),matthews_corrcoef(y_act,y_pred_c),cohen_kappa_score(y_act,y_pred_c))
# Out:
# 0.921182300817481 0.627960967428039 0.5796731538409293 0.574222899621323
